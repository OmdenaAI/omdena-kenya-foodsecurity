# %% [markdown]
# # This notebook trains and predict crop yields using 32 bins histograms

# %%
# !pip install Hub
# Out:
# Requirement already satisfied: Hub in /usr/local/lib/python3.6/dist-packages (1.1.3)
# Requirement already satisfied: psutil>=5.7.3 in /usr/local/lib/python3.6/dist-packages (from Hub) (5.8.0)
# Requirement already satisfied: pathos>=0.2.2 in /usr/local/lib/python3.6/dist-packages (from Hub) (0.2.7)
# Requirement already satisfied: numpy<2,>=1.13.0 in /usr/local/lib/python3.6/dist-packages (from Hub) (1.19.5)
# Requirement already satisfied: zarr==2.6.1 in /usr/local/lib/python3.6/dist-packages (from Hub) (2.6.1)
# Requirement already satisfied: click<8,>=6.7 in /usr/local/lib/python3.6/dist-packages (from Hub) (7.1.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.6/dist-packages (from Hub) (2.23.0)
# Requirement already satisfied: Pillow>=8.0.1 in /usr/local/lib/python3.6/dist-packages (from Hub) (8.1.0)
# Requirement already satisfied: lz4<4,>=3 in /usr/local/lib/python3.6/dist-packages (from Hub) (3.1.1)
# Requirement already satisfied: s3fs==0.4.2 in /usr/local/lib/python3.6/dist-packages (from Hub) (0.4.2)
# Requirement already satisfied: boto3==1.16.39 in /usr/local/lib/python3.6/dist-packages (from Hub) (1.16.39)
# Requirement already satisfied: tqdm==4.54.1 in /usr/local/lib/python3.6/dist-packages (from Hub) (4.54.1)
# Requirement already satisfied: gcsfs==0.6.2 in /usr/local/lib/python3.6/dist-packages (from Hub) (0.6.2)
# Requirement already satisfied: azure-storage-blob==12.6.0 in /usr/local/lib/python3.6/dist-packages (from Hub) (12.6.0)
# Requirement already satisfied: outdated==0.2.0 in /usr/local/lib/python3.6/dist-packages (from Hub) (0.2.0)
# Requirement already satisfied: fsspec==0.8.5 in /usr/local/lib/python3.6/dist-packages (from Hub) (0.8.5)
# Requirement already satisfied: cachey==0.2.1 in /usr/local/lib/python3.6/dist-packages (from Hub) (0.2.1)
# Requirement already satisfied: dill>=0.3.3 in /usr/local/lib/python3.6/dist-packages (from pathos>=0.2.2->Hub) (0.3.3)
# Requirement already satisfied: ppft>=1.6.6.3 in /usr/local/lib/python3.6/dist-packages (from pathos>=0.2.2->Hub) (1.6.6.3)
# Requirement already satisfied: pox>=0.2.9 in /usr/local/lib/python3.6/dist-packages (from pathos>=0.2.2->Hub) (0.2.9)
# Requirement already satisfied: multiprocess>=0.70.11 in /usr/local/lib/python3.6/dist-packages (from pathos>=0.2.2->Hub) (0.70.11.1)
# Requirement already satisfied: numcodecs>=0.6.4 in /usr/local/lib/python3.6/dist-packages (from zarr==2.6.1->Hub) (0.7.2)
# Requirement already satisfied: asciitree in /usr/local/lib/python3.6/dist-packages (from zarr==2.6.1->Hub) (0.3.3)
# Requirement already satisfied: fasteners in /usr/local/lib/python3.6/dist-packages (from zarr==2.6.1->Hub) (0.16)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2->Hub) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2->Hub) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2->Hub) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2->Hub) (2020.12.5)
# Requirement already satisfied: botocore>=1.12.91 in /usr/local/lib/python3.6/dist-packages (from s3fs==0.4.2->Hub) (1.19.55)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3==1.16.39->Hub) (0.10.0)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from boto3==1.16.39->Hub) (0.3.4)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from gcsfs==0.6.2->Hub) (4.4.2)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.6/dist-packages (from gcsfs==0.6.2->Hub) (0.4.2)
# Requirement already satisfied: google-auth>=1.2 in /usr/local/lib/python3.6/dist-packages (from gcsfs==0.6.2->Hub) (1.17.2)
# Requirement already satisfied: msrest>=0.6.10 in /usr/local/lib/python3.6/dist-packages (from azure-storage-blob==12.6.0->Hub) (0.6.19)
# Requirement already satisfied: azure-core<2.0.0,>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from azure-storage-blob==12.6.0->Hub) (1.10.0)
# Requirement already satisfied: cryptography>=2.1.4 in /usr/local/lib/python3.6/dist-packages (from azure-storage-blob==12.6.0->Hub) (3.3.1)
# Requirement already satisfied: littleutils in /usr/local/lib/python3.6/dist-packages (from outdated==0.2.0->Hub) (0.2.2)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.6/dist-packages (from cachey==0.2.1->Hub) (1.0.1)
# Requirement already satisfied: six>=1.7.3 in /usr/local/lib/python3.6/dist-packages (from ppft>=1.6.6.3->pathos>=0.2.2->Hub) (1.15.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.6/dist-packages (from botocore>=1.12.91->s3fs==0.4.2->Hub) (2.8.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib->gcsfs==0.6.2->Hub) (1.3.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.2->gcsfs==0.6.2->Hub) (4.2.0)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.2->gcsfs==0.6.2->Hub) (51.1.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.2->gcsfs==0.6.2->Hub) (4.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.2->gcsfs==0.6.2->Hub) (0.2.8)
# Requirement already satisfied: isodate>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from msrest>=0.6.10->azure-storage-blob==12.6.0->Hub) (0.6.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.6/dist-packages (from cryptography>=2.1.4->azure-storage-blob==12.6.0->Hub) (1.14.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs==0.6.2->Hub) (3.1.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<5,>=3.1.4; python_version >= "3"->google-auth>=1.2->gcsfs==0.6.2->Hub) (0.4.8)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob==12.6.0->Hub) (2.20)

# %%
import tensorflow as tf
from hub import Dataset
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
import numpy as np
import os
print(tf.__version__)
# check if notebook is using GPU
tf.test.gpu_device_name()
# Out:
# 2.4.0
# ''

# %% [markdown]
# ### Functions

# %% [markdown]
# ### Load data from ActiveLoop

# %%
crop_type = 'millet'

print("Load data from ActiveLoop ...")

###### MAIZE ########
if crop_type.lower() == 'maize':
  tag1 = "margauxmforsythe/SouthSudan_departments_histograms_weeks_19_30_Maize" # 2010, 2011, 2014, 2015
  tag2 = "margauxmforsythe/Ethiopia_histograms_weeks_19_30_Maize" # 2004, 2013, 2015, 2016

  tag3 = "margauxmforsythe/Senegal_IPAR_histograms_weeks_19_30_Maize"

  ds1 = Dataset(tag1)
  ds2 = Dataset(tag2)
  ds3 = Dataset(tag3)
  
  print("Dataset {} shape:".format(tag1, ds1["histograms"].compute().shape))
  print("Dataset {} shape:".format(ds2["histograms"].compute().shape))

  histograms = np.concatenate((ds1["histograms"].compute(), ds2["histograms"].compute(), ds3["histograms"].compute()), axis=0)
  yields_list = np.concatenate((ds1["yields"].compute(), ds2["yields"].compute(), ds3["yields"].compute()), axis=0)

  print("Datasets combined, histograms set's shape is {}".format(histograms.shape))
  print("Data loaded from {}, {} and {}".format(tag1, tag2, tag3))

###### RICE ########
if crop_type.lower() == 'rice':
  tag1 = "margauxmforsythe/Senegal_histograms_weeks_19_30_IPAR_Rice_CSC_2014_augmented" 
  tag2 = "margauxmforsythe/Senegal_histograms_weeks_19_30_IPAR_Maize_2014_augmented_2"

  ds1 = Dataset(tag1)
  ds2 = Dataset(tag2)
  print(ds1["histograms"].compute().shape)
  print(ds2["histograms"].compute().shape)
  histograms = np.concatenate((ds1["histograms"].compute(), ds2["histograms"].compute()), axis=0)
  yields_list = np.concatenate((ds1["yields"].compute(), ds2["yields"].compute()), axis=0)
  print(histograms.shape)
  print("Data loaded from {} and {}".format(tag1, tag2))
  
###### MILLET ########
if crop_type.lower() == 'millet':
  tag = "margauxmforsythe/Senegal_IPAR_histograms_weeks_21_30_Millet"
  # tag = "margauxmforsythe/Senegal_IPAR_histograms_weeks_21_30_Millet_augmented"
  ds = Dataset(tag)
  histograms = ds["histograms"].compute()
  yields_list = ds["yields"].compute()

  print("Data loaded from {}".format(tag))

if crop_type.lower() != 'millet' and crop_type.lower() != 'maize' and crop_type.lower() != 'rice': 
  print("Please choose a crop type between maize and millet")

yields = []
for i in range(0,len(yields_list)):
    yields.append(float(yields_list[i][0]))

print("There are {} yield values for training ".format(len(yields)))
# Out:
# Load data from ActiveLoop ...
# Data loaded from margauxmforsythe/Senegal_IPAR_histograms_weeks_21_30_Millet
# There are 1018 yield values for training

# %%
# Get image width, height and channels from the dataset
img_width = histograms[0].shape[0]
img_height = histograms[0].shape[1]
batch_size = 16
channels = histograms[0].shape[2]
shape = (img_width, img_height, channels)
print("Shape input images: {}".format(shape)) # (bins*time steps*bands)

image_count = histograms.shape[0]
print("Image count: {}".format(image_count))
CNN_LSTM = True

# With CNN_LSTM, we need to re arrange the data to (time steps*1*bins*bands)
if CNN_LSTM:
  histograms_CNN_LSTM = []
  for i in range(image_count):
    histogram_all_timestamps_transposed = np.transpose(histograms[i], (1,0,2))
    timestamps = []
    for j in range(histograms[i].shape[1]): # going through all timestamps
      timestamps.append(np.expand_dims(histogram_all_timestamps_transposed[j], axis=0))
    histograms_CNN_LSTM.append(timestamps)
  histograms = histograms_CNN_LSTM
# Out:
# Shape input images: (32, 9, 9)
# Image count: 1018

# %%
assert len(histograms) == len(yields)
list_ds = tf.data.Dataset.from_tensor_slices((histograms, yields))
print("Total files: {}".format(image_count))
# Out:
# Total files: 1018

# %%
train_size = int(0.8 * image_count)
val_size = int(0.1 * image_count)
test_size = int(0.1 * image_count)

list_ds = list_ds.shuffle(len(list_ds))
test_ds = list_ds.take(test_size)
train_ds = list_ds.skip(test_size)
val_ds = train_ds.take(val_size)
train_ds = train_ds.skip(val_size)

n_training_files = len(train_ds)
print("Total files: {}".format(len(histograms)))
print("Training files: {}".format(len(train_ds)))
print("Validation files: {}".format(len(val_ds)))

AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache()
train_ds = train_ds.shuffle(len(train_ds)).repeat()
train_ds = train_ds.batch(batch_size)

val_ds = val_ds.cache()
val_ds = val_ds.shuffle(val_size)
val_ds = val_ds.batch(val_size)

test_ds = test_ds.cache()
test_ds = test_ds.batch(len(test_ds))
# Out:
# Total files: 1018
# Training files: 816
# Validation files: 101

# %% [markdown]
# ### Display first band images in batch to check the data is correct

# %%
image_batch_train, label_batch_train = next(iter(train_ds))
image_batch_val, label_batch_val= next(iter(val_ds))
image_batch_test, label_batch_test= next(iter(test_ds))

print(image_batch_train.shape)
if not CNN_LSTM:
  # Check if images are correct
  plt.figure(figsize=(10, 10))
  plt.suptitle("all bands first image")
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image_batch_train[0][:,:,i].numpy())
    label = label_batch_train[0]
    plt.title(label.numpy())
    plt.axis("off")

  plt.show()
else:
  input_shape_cnn_lstm = (image_batch_train.shape[1], image_batch_train.shape[2], 
                          image_batch_train.shape[3], image_batch_train.shape[4])
  print("input_shape_cnn_lstm: {} = (timestamps*1*bins*bands)".format(input_shape_cnn_lstm))
  input_shape_cnn = (image_batch_train.shape[2], image_batch_train.shape[3], image_batch_train.shape[4])
  print("input_shape_cnn: {} = (1*bins*bands)".format(input_shape_cnn))
# Out:
# (16, 9, 1, 32, 9)
# input_shape_cnn_lstm: (9, 1, 32, 9) = (timestamps*1*bins*bands)
# input_shape_cnn: (1, 32, 9) = (1*bins*bands)

# %%
indexes_list = []
for i in range(len(yields)):
  indexes_list.append(i)

plt.figure(figsize=(7,5))
plt.title("Plot yields (T/ha) in the dataset")
plt.bar(indexes_list, yields)
# Out:
# <BarContainer object of 1018 artists>

# %% [markdown]
# ## Build Model: CNN-LSTM

# %%
if CNN_LSTM:
  # CNN-LSTM 
  # https://www.mdpi.com/1424-8220/19/20/4363/htm
  from keras.layers.wrappers import TimeDistributed
  from keras.layers import *
  from keras import regularizers
  model=models.Sequential()

  model.add(TimeDistributed(Conv2D(32, (1, 2), activation='relu',
                                   kernel_regularizer=regularizers.l2(0.001),
                                   input_shape=(input_shape_cnn)), input_shape=input_shape_cnn_lstm))
  model.add(TimeDistributed(BatchNormalization()))
  model.add(TimeDistributed(MaxPooling2D(pool_size=(1, 2))))

  model.add(TimeDistributed(Conv2D(64, (1, 2), activation='relu',
                                   kernel_regularizer=regularizers.l2(0.001))))
  model.add(TimeDistributed(BatchNormalization()))
  model.add(TimeDistributed(MaxPooling2D(pool_size=(1, 2))))

  model.add(TimeDistributed(Flatten()))
  model.add(LSTM(256, return_sequences=True, activation='relu', dropout=0.25));

  model.add(TimeDistributed(Dense(64)))
  model.add(TimeDistributed(Flatten()))
  model.add(TimeDistributed(Dropout(0.5)))
  model.add(TimeDistributed(Dense(1)))
  model.add(GlobalAveragePooling1D(name="global_avg_flow"))

  model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed (TimeDistri (None, 9, 1, 31, 32)      608
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 9, 1, 31, 32)      128
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 9, 1, 15, 32)      0
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, 9, 1, 14, 64)      4160
# _________________________________________________________________
# time_distributed_4 (TimeDist (None, 9, 1, 14, 64)      256
# _________________________________________________________________
# time_distributed_5 (TimeDist (None, 9, 1, 7, 64)       0
# _________________________________________________________________
# time_distributed_6 (TimeDist (None, 9, 448)            0
# _________________________________________________________________
# lstm (LSTM)                  (None, 9, 256)            721920
# _________________________________________________________________
# time_distributed_7 (TimeDist (None, 9, 64)             16448
# _________________________________________________________________
# time_distributed_8 (TimeDist (None, 9, 64)             0
# _________________________________________________________________
# time_distributed_9 (TimeDist (None, 9, 64)             0
# _________________________________________________________________
# time_distributed_10 (TimeDis (None, 9, 1)              65
# _________________________________________________________________
# global_avg_flow (GlobalAvera (None, 1)                 0
# =================================================================
# Total params: 743,585
# Trainable params: 743,393
# Non-trainable params: 192
# _________________________________________________________________

# %%
initial_learning_rate = 0.0001

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=initial_learning_rate),
              loss=tf.keras.losses.MeanSquaredError(),
              metrics=['accuracy', tf.keras.metrics.RootMeanSquaredError(name='RMSE'), tf.keras.losses.MeanSquaredError(name='MSE')])

# %% [markdown]
# ### Create Callbacks for model fit

# %%
checkpoint_file = 'checkpoint_{}_b{}_CNN-LSTM_IPAR_data.h5'.format(crop_type, batch_size)
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath= checkpoint_file,
    format='h5',
    verbose=1,
    save_weights_only=True,
    monitor='val_loss',
    mode='min',
    save_best_only=True)

# reducelronplateau = tf.keras.callbacks.ReduceLROnPlateau(
#     monitor='val_loss', factor=0.1, patience=5, verbose=1,
#     mode='min', min_lr=1e-10)

early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss',mode='min', patience=20, verbose=1)

# %% [markdown]
# ## Training

# %%
print("Train ... ")

model.trainable = True
history = model.fit(train_ds,
                    epochs=1000,
                    steps_per_epoch=n_training_files//batch_size,
                    validation_data=val_ds,
                    verbose=1,
                    callbacks=[model_checkpoint_callback, early_stop])
# Out:
# Train ...
# Epoch 1/1000
# 51/51 [==============================] - 7s 89ms/step - loss: 1.0845 - accuracy: 0.0209 - RMSE: 0.9949 - MSE: 1.0275 - val_loss: 3.3384 - val_accuracy: 0.0000e+00 - val_RMSE: 1.8115 - val_MSE: 3.2815
#
# Epoch 00001: val_loss improved from inf to 3.33842, saving model to checkpoint_millet_b16_CNN-LSTM_IPAR_data.h5
# Epoch 2/1000
# 51/51 [==============================] - 4s 77ms/step - loss: 0.8080 - accuracy: 0.0371 - RMSE: 0.8309 - MSE: 0.7511 - val_loss: 3.4890 - val_accuracy: 0.0000e+00 - val_RMSE: 1.8526 - val_MSE: 3.4320
#
# Epoch 00002: val_loss did not improve from 3.33842
# Epoch 3/1000
# 51/51 [==============================] - 4s 72ms/step - loss: 0.9829 - accuracy: 0.0440 - RMSE: 0.9337 - MSE: 0.9260 - val_loss: 3.6086 - val_accuracy: 0.0000e+00 - val_RMSE: 1.8846 - val_MSE: 3.5517
#
# Epoch 00003: val_loss did not improve from 3.33842
# Epoch 4/1000
# 51/51 [==============================] - 4s 75ms/step - loss: 1.5749 - accuracy: 0.0535 - RMSE: 1.1961 - MSE: 1.5180 - val_loss: 3.7178 - val_accuracy: 0.0000e+00 - val_RMSE: 1.9134 - val_MSE: 3.6609
#
# Epoch 00004: val_loss did not improve from 3.33842
# Epoch 5/1000
# 51/51 [==============================] - 4s 76ms/step - loss: 0.7141 - accuracy: 0.0444 - RMSE: 0.7970 - MSE: 0.6572 - val_loss: 3.6924 - val_accuracy: 0.0000e+00 - val_RMSE: 1.9067 - val_MSE: 3.6356
#
# Epoch 00005: val_loss did not improve from 3.33842
# Epoch 6/1000
# 51/51 [==============================] - 4s 73ms/step - loss: 0.8325 - accuracy: 0.0388 - RMSE: 0.8590 - MSE: 0.7757 - val_loss: 3.5352 - val_accuracy: 0.0000e+00 - val_RMSE: 1.8650 - val_MSE: 3.4784
#
# Epoch 00006: val_loss did not improve from 3.33842
# Epoch 7/1000
# 51/51 [==============================] - 4s 75ms/step - loss: 1.0542 - accuracy: 0.0598 - RMSE: 0.9848 - MSE: 0.9975 - val_loss: 3.3573 - val_accuracy: 0.0000e+00 - val_RMSE: 1.8167 - val_MSE: 3.3006
#
# Epoch 00007: val_loss did not improve from 3.33842
# Epoch 8/1000
# 51/51 [==============================] - 4s 74ms/step - loss: 0.9377 - accuracy: 0.0520 - RMSE: 0.9178 - MSE: 0.8810 - val_loss: 3.1845 - val_accuracy: 0.0000e+00 - val_RMSE: 1.7686 - val_MSE: 3.1278
#
# Epoch 00008: val_loss improved from 3.33842 to 3.18448, saving model to checkpoint_millet_b16_CNN-LSTM_IPAR_data.h5
# Epoch 9/1000
# 51/51 [==============================] - 4s 75ms/step - loss: 0.9368 - accuracy: 0.0465 - RMSE: 0.9242 - MSE: 0.8801 - val_loss: 2.8860 - val_accuracy: 0.0000e+00 - val_RMSE: 1.6821 - val_MSE: 2.8293
#
# Epoch 00009: val_loss improved from 3.18448 to 2.88596, saving model to checkpoint_millet_b16_CNN-LSTM_IPAR_data.h5
# Epoch 10/1000
# 51/51 [==============================] - 4s 74ms/step - loss: 0.5805 - accuracy: 0.0685 - RMSE: 0.7043 - MSE: 0.5238 - val_loss: 2.7214 - val_accuracy: 0.0000e+00 - val_RMSE: 1.6324 - val_MSE: 2.6647
#
# Epoch 00010: val_loss improved from 2.88596 to 2.72136, saving model to checkpoint_millet_b16_CNN-LSTM_IPAR_data.h5
# Epoch 11/1000
# 51/51 [==============================] - 4s 72ms/step - loss: 1.3806 - accuracy: 0.0510 - RMSE: 1.1032 - MSE: 1.3240 - val_loss: 2.6529 - val_accuracy: 0.0099 - val_RMSE: 1.6113 - val_MSE: 2.5963
#
# Epoch 00011: val_loss improved from 2.72136 to 2.65288, saving model to checkpoint_millet_b16_CNN-LSTM_IPAR_data.h5
# Epoch 12/1000
# 51/51 [==============================] - 4s 74ms/step - loss: 1.0877 - accuracy: 0.0381 - RMSE: 0.9959 - MSE: 1.0312 - val_loss: 2.4877 - val_accuracy: 0.0099 - val_RMSE: 1.5592 - val_MSE: 2.4312
#
# Epoch 00012: val_loss improved from 2.65288 to 2.48773, saving model to checkpoint_millet_b16_CNN-LSTM_IPAR_data.h5
# Epoch 13/1000
# 51/51 [==============================] - 4s 77ms/step - loss: 1.0333 - accuracy: 0.0492 - RMSE: 0.9494 - MSE: 0.9767 - val_loss: 2.3609 - val_accuracy: 0.0297 - val_RMSE: 1.5180 - val_MSE: 2.3044
#
# Epoch 00013: val_loss improved from 2.48773 to 2.36089, saving model to checkpoint_millet_b16_CNN-LSTM_IPAR_data.h5
# Epoch 14/1000
# 51/51 [==============================] - 4s 73ms/step - loss: 1.0495 - accuracy: 0.0571 - RMSE: 0.9446 - MSE: 0.9930 - val_loss: 2.2174 - val_accuracy: 0.0396 - val_RMSE: 1.4700 - val_MSE: 2.1609
#
# Epoch 00014: val_loss improved from 2.36089 to 2.21739, saving model to checkpoint_millet_b16_CNN-LSTM_IPAR_data.h5
# Epoch 15/1000
# 51/51 [==============================] - 4s 74ms/step - loss: 0.4773 - accuracy: 0.0556 - RMSE: 0.6275 - MSE: 0.4208 - val_loss: 2.1357 - val_accuracy: 0.0792 - val_RMSE: 1.4420 - val_MSE: 2.0792
#
# Epoch 00015: val_loss improved from 2.21739 to 2.13567, saving model to checkpoint_millet_b16_CNN-LSTM_IPAR_data.h5
# Epoch 16/1000
# 51/51 [==============================] - 4s 75ms/step - loss: 1.2104 - accuracy: 0.0603 - RMSE: 1.0460 - MSE: 1.1540 - val_loss: 2.1369 - val_accuracy: 0.0495 - val_RMSE: 1.4424 - val_MSE: 2.0805
#
# Epoch 00016: val_loss did not improve from 2.13567
# Epoch 17/1000
# 51/51 [==============================] - 4s 76ms/step - loss: 0.7802 - accuracy: 0.0479 - RMSE: 0.8323 - MSE: 0.7238 - val_loss: 2.0164 - val_accuracy: 0.0891 - val_RMSE: 1.4000 - val_MSE: 1.9601
#
# Epoch 00017: val_loss improved from 2.13567 to 2.01643, saving model to checkpoint_millet_b16_CNN-LSTM_IPAR_data.h5
# Epoch 18/1000
# 51/51 [==============================] - 4s 75ms/step - loss: 0.4692 - accuracy: 0.0639 - RMSE: 0.6381 - MSE: 0.4129 - val_loss: 1.9818 - val_accuracy: 0.0891 - val_RMSE: 1.3876 - val_MSE: 1.9255
#
# Epoch 00018: val_loss improved from 2.01643 to 1.98182, saving model to checkpoint_millet_b16_CNN-LSTM_IPAR_data.h5
# Epoch 19/1000
# 51/51 [==============================] - 4s 75ms/step - loss: 0.7839 - accuracy: 0.0557 - RMSE: 0.8435 - MSE: 0.7276 - val_loss: 1.9088 - val_accuracy: 0.0297 - val_RMSE: 1.3611 - val_MSE: 1.8525
#
# Epoch 00019: val_loss improved from 1.98182 to 1.90878, saving model to checkpoint_millet_b16_CNN-LSTM_IPAR_data.h5
# Epoch 20/1000
# 51/51 [==============================] - 4s 75ms/step - loss: 1.1997 - accuracy: 0.0449 - RMSE: 1.0180 - MSE: 1.1435 - val_loss: 1.9464 - val_accuracy: 0.0198 - val_RMSE: 1.3748 - val_MSE: 1.8902
#
# Epoch 00020: val_loss did not improve from 1.90878
# Epoch 21/1000
# 51/51 [==============================] - 4s 76ms/step - loss: 0.3836 - accuracy: 0.0495 - RMSE: 0.5555 - MSE: 0.3273 - val_loss: 1.7042 - val_accuracy: 0.0594 - val_RMSE: 1.2837 - val_MSE: 1.6480
#
# Epoch 00021: val_loss improved from 1.90878 to 1.70419, saving model to checkpoint_millet_b16_CNN-LSTM_IPAR_data.h5
# Epoch 22/1000
# 51/51 [==============================] - 4s 78ms/step - loss: 0.4566 - accuracy: 0.0466 - RMSE: 0.6185 - MSE: 0.4004 - val_loss: 1.6177 - val_accuracy: 0.0396 - val_RMSE: 1.2496 - val_MSE: 1.5615
#
# Epoch 00022: val_loss improved from 1.70419 to 1.61774, saving model to checkpoint_millet_b16_CNN-LSTM_IPAR_data.h5
# Epoch 23/1000
# 51/51 [==============================] - 4s 78ms/step - loss: 0.3664 - accuracy: 0.0452 - RMSE: 0.5503 - MSE: 0.3102 - val_loss: 1.3439 - val_accuracy: 0.0495 - val_RMSE: 1.1348 - val_MSE: 1.2877
#
# Epoch 00023: val_loss improved from 1.61774 to 1.34387, saving model to checkpoint_millet_b16_CNN-LSTM_IPAR_data.h5
# Epoch 24/1000
# 51/51 [==============================] - 4s 75ms/step - loss: 0.6514 - accuracy: 0.0436 - RMSE: 0.7649 - MSE: 0.5952 - val_loss: 1.3622 - val_accuracy: 0.0792 - val_RMSE: 1.1428 - val_MSE: 1.3061
#
# Epoch 00024: val_loss did not improve from 1.34387
# Epoch 25/1000
# 51/51 [==============================] - 4s 76ms/step - loss: 0.5379 - accuracy: 0.0470 - RMSE: 0.6796 - MSE: 0.4817 - val_loss: 1.0512 - val_accuracy: 0.0693 - val_RMSE: 0.9976 - val_MSE: 0.9951
#
# Epoch 00025: val_loss improved from 1.34387 to 1.05125, saving model to checkpoint_millet_b16_CNN-LSTM_IPAR_data.h5
# Epoch 26/1000
# 51/51 [==============================] - 4s 73ms/step - loss: 0.4481 - accuracy: 0.0561 - RMSE: 0.6201 - MSE: 0.3920 - val_loss: 1.0523 - val_accuracy: 0.0396 - val_RMSE: 0.9981 - val_MSE: 0.9962
#
# Epoch 00026: val_loss did not improve from 1.05125
# Epoch 27/1000
# 51/51 [==============================] - 4s 73ms/step - loss: 0.3358 - accuracy: 0.0423 - RMSE: 0.5207 - MSE: 0.2797 - val_loss: 0.9857 - val_accuracy: 0.0396 - val_RMSE: 0.9642 - val_MSE: 0.9296
#
# Epoch 00027: val_loss improved from 1.05125 to 0.98568, saving model to checkpoint_millet_b16_CNN-LSTM_IPAR_data.h5
# Epoch 28/1000
# 51/51 [==============================] - 4s 74ms/step - loss: 0.3995 - accuracy: 0.0438 - RMSE: 0.5790 - MSE: 0.3434 - val_loss: 0.6567 - val_accuracy: 0.0594 - val_RMSE: 0.7750 - val_MSE: 0.6007
#
# Epoch 00028: val_loss improved from 0.98568 to 0.65674, saving model to checkpoint_millet_b16_CNN-LSTM_IPAR_data.h5
# Epoch 29/1000
# 51/51 [==============================] - 4s 75ms/step - loss: 0.5175 - accuracy: 0.0323 - RMSE: 0.6701 - MSE: 0.4614 - val_loss: 0.6109 - val_accuracy: 0.0594 - val_RMSE: 0.7449 - val_MSE: 0.5548
#
# Epoch 00029: val_loss improved from 0.65674 to 0.61087, saving model to checkpoint_millet_b16_CNN-LSTM_IPAR_data.h5
# Epoch 30/1000
# 51/51 [==============================] - 4s 72ms/step - loss: 0.3540 - accuracy: 0.0520 - RMSE: 0.5360 - MSE: 0.2979 - val_loss: 0.6989 - val_accuracy: 0.0792 - val_RMSE: 0.8018 - val_MSE: 0.6429
#
# Epoch 00030: val_loss did not improve from 0.61087
# Epoch 31/1000
# 51/51 [==============================] - 4s 73ms/step - loss: 0.3835 - accuracy: 0.0303 - RMSE: 0.5706 - MSE: 0.3275 - val_loss: 0.7933 - val_accuracy: 0.0396 - val_RMSE: 0.8587 - val_MSE: 0.7373
#
# Epoch 00031: val_loss did not improve from 0.61087
# Epoch 32/1000
# 51/51 [==============================] - 4s 74ms/step - loss: 0.4261 - accuracy: 0.0445 - RMSE: 0.6002 - MSE: 0.3701 - val_loss: 0.3053 - val_accuracy: 0.0693 - val_RMSE: 0.4994 - val_MSE: 0.2494
#
# Epoch 00032: val_loss improved from 0.61087 to 0.30533, saving model to checkpoint_millet_b16_CNN-LSTM_IPAR_data.h5
# Epoch 33/1000
# 51/51 [==============================] - 4s 74ms/step - loss: 0.3917 - accuracy: 0.0526 - RMSE: 0.5746 - MSE: 0.3357 - val_loss: 0.3011 - val_accuracy: 0.0594 - val_RMSE: 0.4951 - val_MSE: 0.2451
#
# Epoch 00033: val_loss improved from 0.30533 to 0.30110, saving model to checkpoint_millet_b16_CNN-LSTM_IPAR_data.h5
# Epoch 34/1000
# 51/51 [==============================] - 4s 75ms/step - loss: 0.3746 - accuracy: 0.0509 - RMSE: 0.5599 - MSE: 0.3186 - val_loss: 0.8639 - val_accuracy: 0.0594 - val_RMSE: 0.8989 - val_MSE: 0.8079
#
# Epoch 00034: val_loss did not improve from 0.30110
# Epoch 35/1000
# 51/51 [==============================] - 4s 75ms/step - loss: 0.3755 - accuracy: 0.0343 - RMSE: 0.5632 - MSE: 0.3195 - val_loss: 0.9003 - val_accuracy: 0.0495 - val_RMSE: 0.9189 - val_MSE: 0.8443
#
# Epoch 00035: val_loss did not improve from 0.30110
# Epoch 36/1000
# 51/51 [==============================] - 4s 76ms/step - loss: 0.2956 - accuracy: 0.0529 - RMSE: 0.4867 - MSE: 0.2397 - val_loss: 0.4285 - val_accuracy: 0.0891 - val_RMSE: 0.6104 - val_MSE: 0.3725
#
# Epoch 00036: val_loss did not improve from 0.30110
# Epoch 37/1000
# 51/51 [==============================] - 4s 77ms/step - loss: 0.3783 - accuracy: 0.0511 - RMSE: 0.5656 - MSE: 0.3224 - val_loss: 0.2868 - val_accuracy: 0.0693 - val_RMSE: 0.4805 - val_MSE: 0.2309
#
# Epoch 00037: val_loss improved from 0.30110 to 0.28677, saving model to checkpoint_millet_b16_CNN-LSTM_IPAR_data.h5
# Epoch 38/1000
# 51/51 [==============================] - 4s 74ms/step - loss: 0.3637 - accuracy: 0.0456 - RMSE: 0.5465 - MSE: 0.3078 - val_loss: 0.3117 - val_accuracy: 0.0594 - val_RMSE: 0.5058 - val_MSE: 0.2558
#
# Epoch 00038: val_loss did not improve from 0.28677
# Epoch 39/1000
# 51/51 [==============================] - 4s 77ms/step - loss: 0.2846 - accuracy: 0.0466 - RMSE: 0.4762 - MSE: 0.2287 - val_loss: 1.1011 - val_accuracy: 0.0297 - val_RMSE: 1.0224 - val_MSE: 1.0452
#
# Epoch 00039: val_loss did not improve from 0.28677
# Epoch 40/1000
# 51/51 [==============================] - 4s 78ms/step - loss: 0.5173 - accuracy: 0.0289 - RMSE: 0.6707 - MSE: 0.4615 - val_loss: 1.3686 - val_accuracy: 0.0594 - val_RMSE: 1.1458 - val_MSE: 1.3128
#
# Epoch 00040: val_loss did not improve from 0.28677
# Epoch 41/1000
# 51/51 [==============================] - 4s 75ms/step - loss: 0.5211 - accuracy: 0.0708 - RMSE: 0.6608 - MSE: 0.4652 - val_loss: 0.7618 - val_accuracy: 0.0594 - val_RMSE: 0.8402 - val_MSE: 0.7060
#
# Epoch 00041: val_loss did not improve from 0.28677
# Epoch 42/1000
# 51/51 [==============================] - 4s 76ms/step - loss: 0.3393 - accuracy: 0.0404 - RMSE: 0.5222 - MSE: 0.2834 - val_loss: 0.3304 - val_accuracy: 0.0495 - val_RMSE: 0.5240 - val_MSE: 0.2745
#
# Epoch 00042: val_loss did not improve from 0.28677
# Epoch 43/1000
# 51/51 [==============================] - 4s 78ms/step - loss: 0.3331 - accuracy: 0.0316 - RMSE: 0.5141 - MSE: 0.2773 - val_loss: 0.1714 - val_accuracy: 0.0594 - val_RMSE: 0.3400 - val_MSE: 0.1156
#
# Epoch 00043: val_loss improved from 0.28677 to 0.17141, saving model to checkpoint_millet_b16_CNN-LSTM_IPAR_data.h5
# Epoch 44/1000
# 51/51 [==============================] - 4s 81ms/step - loss: 0.2490 - accuracy: 0.0442 - RMSE: 0.4381 - MSE: 0.1932 - val_loss: 0.1615 - val_accuracy: 0.0792 - val_RMSE: 0.3251 - val_MSE: 0.1057
#
# Epoch 00044: val_loss improved from 0.17141 to 0.16151, saving model to checkpoint_millet_b16_CNN-LSTM_IPAR_data.h5
# Epoch 45/1000
# 51/51 [==============================] - 4s 73ms/step - loss: 0.2654 - accuracy: 0.0559 - RMSE: 0.4560 - MSE: 0.2096 - val_loss: 0.3531 - val_accuracy: 0.0495 - val_RMSE: 0.5453 - val_MSE: 0.2973
#
# Epoch 00045: val_loss did not improve from 0.16151
# Epoch 46/1000
# 51/51 [==============================] - 4s 76ms/step - loss: 0.4853 - accuracy: 0.0487 - RMSE: 0.6369 - MSE: 0.4295 - val_loss: 1.9341 - val_accuracy: 0.0594 - val_RMSE: 1.3705 - val_MSE: 1.8784
#
# Epoch 00046: val_loss did not improve from 0.16151
# Epoch 47/1000
# 51/51 [==============================] - 4s 77ms/step - loss: 0.8991 - accuracy: 0.0525 - RMSE: 0.8487 - MSE: 0.8433 - val_loss: 1.6610 - val_accuracy: 0.0792 - val_RMSE: 1.2670 - val_MSE: 1.6053
#
# Epoch 00047: val_loss did not improve from 0.16151
# Epoch 48/1000
# 51/51 [==============================] - 4s 76ms/step - loss: 0.3143 - accuracy: 0.0529 - RMSE: 0.4844 - MSE: 0.2585 - val_loss: 1.3159 - val_accuracy: 0.0495 - val_RMSE: 1.1226 - val_MSE: 1.2602
#
# Epoch 00048: val_loss did not improve from 0.16151
# Epoch 49/1000
# 51/51 [==============================] - 4s 75ms/step - loss: 0.6956 - accuracy: 0.0484 - RMSE: 0.7848 - MSE: 0.6399 - val_loss: 1.2115 - val_accuracy: 0.0792 - val_RMSE: 1.0750 - val_MSE: 1.1557
#
# Epoch 00049: val_loss did not improve from 0.16151
# Epoch 50/1000
# 51/51 [==============================] - 4s 76ms/step - loss: 0.3808 - accuracy: 0.0578 - RMSE: 0.5581 - MSE: 0.3250 - val_loss: 0.7906 - val_accuracy: 0.0792 - val_RMSE: 0.8573 - val_MSE: 0.7349
#
# Epoch 00050: val_loss did not improve from 0.16151
# Epoch 51/1000
# 51/51 [==============================] - 4s 78ms/step - loss: 0.2187 - accuracy: 0.0381 - RMSE: 0.4008 - MSE: 0.1630 - val_loss: 0.5084 - val_accuracy: 0.0792 - val_RMSE: 0.6728 - val_MSE: 0.4527
#
# Epoch 00051: val_loss did not improve from 0.16151
# Epoch 52/1000
# 51/51 [==============================] - 4s 76ms/step - loss: 0.2824 - accuracy: 0.0472 - RMSE: 0.4746 - MSE: 0.2266 - val_loss: 0.3339 - val_accuracy: 0.0495 - val_RMSE: 0.5275 - val_MSE: 0.2782
#
# Epoch 00052: val_loss did not improve from 0.16151
# Epoch 53/1000
# 51/51 [==============================] - 4s 76ms/step - loss: 0.2446 - accuracy: 0.0611 - RMSE: 0.4300 - MSE: 0.1889 - val_loss: 0.2218 - val_accuracy: 0.0792 - val_RMSE: 0.4076 - val_MSE: 0.1661
#
# Epoch 00053: val_loss did not improve from 0.16151
# Epoch 54/1000
# 51/51 [==============================] - 4s 77ms/step - loss: 0.3802 - accuracy: 0.0447 - RMSE: 0.5533 - MSE: 0.3245 - val_loss: 0.1965 - val_accuracy: 0.0792 - val_RMSE: 0.3753 - val_MSE: 0.1408
#
# Epoch 00054: val_loss did not improve from 0.16151
# Epoch 55/1000
# 51/51 [==============================] - 4s 79ms/step - loss: 0.2271 - accuracy: 0.0382 - RMSE: 0.4118 - MSE: 0.1714 - val_loss: 0.1637 - val_accuracy: 0.0792 - val_RMSE: 0.3286 - val_MSE: 0.1079
#
# Epoch 00055: val_loss did not improve from 0.16151
# Epoch 56/1000
# 51/51 [==============================] - 4s 78ms/step - loss: 0.1958 - accuracy: 0.0618 - RMSE: 0.3737 - MSE: 0.1401 - val_loss: 0.1922 - val_accuracy: 0.0693 - val_RMSE: 0.3695 - val_MSE: 0.1365
#
# Epoch 00056: val_loss did not improve from 0.16151
# Epoch 57/1000
# 51/51 [==============================] - 4s 75ms/step - loss: 0.1931 - accuracy: 0.0488 - RMSE: 0.3678 - MSE: 0.1374 - val_loss: 0.2003 - val_accuracy: 0.0495 - val_RMSE: 0.3802 - val_MSE: 0.1446
#
# Epoch 00057: val_loss did not improve from 0.16151
# Epoch 58/1000
# 51/51 [==============================] - 4s 78ms/step - loss: 0.1970 - accuracy: 0.0621 - RMSE: 0.3757 - MSE: 0.1413 - val_loss: 0.1848 - val_accuracy: 0.0792 - val_RMSE: 0.3594 - val_MSE: 0.1291
#
# Epoch 00058: val_loss did not improve from 0.16151
# Epoch 59/1000
# 51/51 [==============================] - 4s 77ms/step - loss: 0.1853 - accuracy: 0.0579 - RMSE: 0.3590 - MSE: 0.1297 - val_loss: 0.1799 - val_accuracy: 0.0792 - val_RMSE: 0.3525 - val_MSE: 0.1243
#
# Epoch 00059: val_loss did not improve from 0.16151
# Epoch 60/1000
# 51/51 [==============================] - 4s 80ms/step - loss: 0.2003 - accuracy: 0.0608 - RMSE: 0.3777 - MSE: 0.1447 - val_loss: 0.1670 - val_accuracy: 0.0693 - val_RMSE: 0.3337 - val_MSE: 0.1114
#
# Epoch 00060: val_loss did not improve from 0.16151
# Epoch 61/1000
# 51/51 [==============================] - 4s 77ms/step - loss: 0.2112 - accuracy: 0.0648 - RMSE: 0.3937 - MSE: 0.1556 - val_loss: 0.2190 - val_accuracy: 0.0693 - val_RMSE: 0.4042 - val_MSE: 0.1634
#
# Epoch 00061: val_loss did not improve from 0.16151
# Epoch 62/1000
# 51/51 [==============================] - 4s 77ms/step - loss: 0.1790 - accuracy: 0.0568 - RMSE: 0.3503 - MSE: 0.1233 - val_loss: 0.3352 - val_accuracy: 0.0891 - val_RMSE: 0.5288 - val_MSE: 0.2796
#
# Epoch 00062: val_loss did not improve from 0.16151
# Epoch 63/1000
# 51/51 [==============================] - 4s 75ms/step - loss: 0.2274 - accuracy: 0.0423 - RMSE: 0.4120 - MSE: 0.1718 - val_loss: 0.1686 - val_accuracy: 0.0594 - val_RMSE: 0.3362 - val_MSE: 0.1130
#
# Epoch 00063: val_loss did not improve from 0.16151
# Epoch 64/1000
# 51/51 [==============================] - 4s 77ms/step - loss: 0.2270 - accuracy: 0.0559 - RMSE: 0.4109 - MSE: 0.1715 - val_loss: 0.2134 - val_accuracy: 0.0693 - val_RMSE: 0.3973 - val_MSE: 0.1578
#
# Epoch 00064: val_loss did not improve from 0.16151
# Epoch 00064: early stopping

# %% [markdown]
# ### Plots

# %%
plt.plot(history.history['loss'], label='loss')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.show()

# %%
plt.plot(history.history['RMSE'], label='RMSE')
plt.xlabel('Epoch')
plt.ylabel('RMSE')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.show()

# %%
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('val_loss')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.show()

# %%
plt.plot(history.history['val_RMSE'], label = 'val_RMSE')
plt.xlabel('Epoch')
plt.ylabel('val_RMSE')
plt.ylim([0,1])
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ### Evaluation

# %%
print("\nEvaluating val ds... ")
test_loss, test_acc, test_rmse, test_mse = model.evaluate(val_ds, verbose=1)

print("\nEvaluating test ds (0.1 of all files)... ")
test_loss, test_acc, test_rmse, test_mse = model.evaluate(test_ds, verbose=1)
# Out:
# Evaluating val ds...
# 1/1 [==============================] - 0s 76ms/step - loss: 0.2134 - accuracy: 0.0693 - RMSE: 0.3973 - MSE: 0.1578
#
# Evaluating test ds (0.1 of all files)...
# 1/1 [==============================] - 0s 70ms/step - loss: 0.1720 - accuracy: 0.0198 - RMSE: 0.3412 - MSE: 0.1164

# %% [markdown]
# Evaluate with all 2014 IPAR data

# %%
if crop_type.lower() == 'maize':
  tag_test_IPAR = "margauxmforsythe/Senegal_IPAR_histograms_weeks_19_30_Maize"
if crop_type.lower() == 'millet':
  tag_test_IPAR = "margauxmforsythe/Senegal_IPAR_histograms_weeks_21_30_Millet"
ds_test_IPAR_all = Dataset(tag_test_IPAR)
test_hists = ds_test_IPAR_all["histograms"].compute()
yields_list_test = ds_test_IPAR_all["yields"].compute()
yields_test_IPAR_all = []
for i in range(0,len(yields_list_test)):
    yields_test_IPAR_all.append(float(yields_list_test[i][0]))
  
# TEST set
histograms_CNN_LSTM_test = []
for i in range(len(test_hists)):
  histogram_all_timestamps_transposed = np.transpose(test_hists[i], (1,0,2))
  timestamps = []
  for j in range(test_hists[i].shape[1]): # going through all timestamps
    timestamps.append(np.expand_dims(histogram_all_timestamps_transposed[j], axis=0))
  histograms_CNN_LSTM_test.append(timestamps)
histograms_test_IPAR_all = histograms_CNN_LSTM_test
print("There are now {} (* {} time steps files) splitted per timestamps of shape {} in the dataset".format(shape[1], len(histograms), histograms_CNN_LSTM[0][0].shape))

test_ds = tf.data.Dataset.from_tensor_slices((histograms_test_IPAR_all, yields_test_IPAR_all))
test_ds = test_ds.cache()
test_ds = test_ds.batch(len(test_ds))
image_batch_test, label_batch_test= next(iter(test_ds))
# Out:
# There are now 9 (* 1018 time steps files) splitted per timestamps of shape (1, 32, 9) in the dataset

# %%
model.load_weights(checkpoint_file)
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=initial_learning_rate),
              loss=tf.keras.losses.MeanSquaredError(),
              metrics=['accuracy', tf.keras.metrics.RootMeanSquaredError(name='RMSE'), tf.keras.losses.MeanSquaredError(name='MSE')])

# %%
print("\nEvaluating test ds... ")
test_loss, test_acc, test_rmse, test_mse = model.evaluate(test_ds, verbose=1)
# Out:
# Evaluating test ds...
# 1/1 [==============================] - 1s 1s/step - loss: 0.1851 - accuracy: 0.0540 - RMSE: 0.3596 - MSE: 0.1293

# %% [markdown]
# ### Prediction

# %%
if not CNN_LSTM:
  plt.imshow(image_batch_val[0][:,:,0])
  label = label_batch_val[0].numpy()
  plt.title(label)
  plt.axis("off")
else:
  print("real yield: {}".format(label_batch_val[0].numpy()))
predictions = model.predict(image_batch_val)
print("predictions shape:", predictions.shape)
print("prediction:", predictions[0][0])
# Out:
# real yield: 1.3333333730697632
# predictions shape: (101, 1)
# prediction: 0.90830314

# %%
indexes_list = []
for i in range(len(image_batch_test)):
  indexes_list.append(i)

predictions = model.predict(test_ds)
predictions_array = []
for i in range(len(predictions)):
  predictions_array.append(predictions[i][0])
predictions_array

assert len(predictions_array) == len(label_batch_test.numpy())

plt.figure(figsize=(8,5))
plt.ylabel('yields T/ha')
bar1 = plt.bar(indexes_list,label_batch_test.numpy(),label='real yields', alpha=0.7)
bar2 = plt.bar(indexes_list,predictions_array,label='predicted yields', alpha=0.7)
plt.legend()
plt.ylim([0, 4])
plt.show()

# %%
error = abs(predictions_array - label_batch_test.numpy())
plt.title("Plot of errors between real yield value and predicted one on the test set")
plt.ylim([0, 5])
plt.bar(indexes_list,error)
# Out:
# <BarContainer object of 1018 artists>

# %%
indexes_list = []
for i in range(len(image_batch_test)):
  indexes_list.append(i)

error = abs(predictions_array - label_batch_test.numpy())/label_batch_test.numpy()
plt.title("Plot of percentage errors between real yield value and predicted one on the test set")
plt.ylim([0, 30])
plt.bar(indexes_list,error)
# Out:
# <BarContainer object of 1018 artists>

# %%
for i in range(len(predictions_array)):
  print("{}) Predicted yield {} T/ha // Real yield {} T/ha".format(i, predictions_array[i], label_batch_test.numpy()[i]))
# Out:
# 0) Predicted yield 0.4897463619709015 T/ha // Real yield 0.3333333432674408 T/ha
# 1) Predicted yield 0.6950358152389526 T/ha // Real yield 0.20000000298023224 T/ha
# 2) Predicted yield 0.2947421073913574 T/ha // Real yield 0.0062500000931322575 T/ha
# 3) Predicted yield 0.18281729519367218 T/ha // Real yield 0.02500000037252903 T/ha
# 4) Predicted yield 0.637729823589325 T/ha // Real yield 1.0 T/ha
# 5) Predicted yield 0.964123010635376 T/ha // Real yield 0.8999999761581421 T/ha
# 6) Predicted yield 0.37097564339637756 T/ha // Real yield 0.23333333432674408 T/ha
# 7) Predicted yield 0.9693173170089722 T/ha // Real yield 1.2999999523162842 T/ha
# 8) Predicted yield 0.5071171522140503 T/ha // Real yield 0.05999999865889549 T/ha
# 9) Predicted yield 0.5488135814666748 T/ha // Real yield 0.25 T/ha
# 10) Predicted yield 0.5954135656356812 T/ha // Real yield 0.5249999761581421 T/ha
# 11) Predicted yield 0.08032461255788803 T/ha // Real yield 0.4375 T/ha
# 12) Predicted yield 0.2702009975910187 T/ha // Real yield 0.10000000149011612 T/ha
# 13) Predicted yield 1.040234088897705 T/ha // Real yield 0.3571428656578064 T/ha
# 14) Predicted yield 0.43871623277664185 T/ha // Real yield 0.9750000238418579 T/ha
# 15) Predicted yield 0.4868539571762085 T/ha // Real yield 0.30000001192092896 T/ha
# 16) Predicted yield 6.634739398956299 T/ha // Real yield 8.0 T/ha
# 17) Predicted yield 0.8939359188079834 T/ha // Real yield 1.0 T/ha
# 18) Predicted yield 0.05686238035559654 T/ha // Real yield 0.05999999865889549 T/ha
# 19) Predicted yield 0.8502547740936279 T/ha // Real yield 1.100000023841858 T/ha
# 20) Predicted yield 0.7434722781181335 T/ha // Real yield 0.6666666865348816 T/ha
# 21) Predicted yield 0.5526110529899597 T/ha // Real yield 0.4000000059604645 T/ha
# 22) Predicted yield 0.4301208257675171 T/ha // Real yield 0.3199999928474426 T/ha
# 23) Predicted yield 0.8917791843414307 T/ha // Real yield 1.0 T/ha
# 24) Predicted yield 0.5262717008590698 T/ha // Real yield 0.5400000214576721 T/ha
# 25) Predicted yield 0.6381829380989075 T/ha // Real yield 0.7142857313156128 T/ha
# 26) Predicted yield 0.2602331340312958 T/ha // Real yield 0.17499999701976776 T/ha
# 27) Predicted yield 0.5775916576385498 T/ha // Real yield 0.5 T/ha
# 28) Predicted yield 0.38035017251968384 T/ha // Real yield 0.4000000059604645 T/ha
# 29) Predicted yield 0.30276110768318176 T/ha // Real yield 0.30000001192092896 T/ha
# 30) Predicted yield 0.12309721112251282 T/ha // Real yield 0.46666666865348816 T/ha
# 31) Predicted yield 0.5078917145729065 T/ha // Real yield 0.012000000104308128 T/ha
# 32) Predicted yield 0.3675374388694763 T/ha // Real yield 0.23999999463558197 T/ha
# 33) Predicted yield 1.0349700450897217 T/ha // Real yield 0.30000001192092896 T/ha
# 34) Predicted yield 0.329780638217926 T/ha // Real yield 0.75 T/ha
# 35) Predicted yield 0.9083031415939331 T/ha // Real yield 1.3333333730697632 T/ha
# 36) Predicted yield 0.20234759151935577 T/ha // Real yield 0.15000000596046448 T/ha
# 37) Predicted yield 0.3178832530975342 T/ha // Real yield 0.1666666716337204 T/ha
# 38) Predicted yield 0.8304527997970581 T/ha // Real yield 2.0 T/ha
# 39) Predicted yield 0.39740654826164246 T/ha // Real yield 0.03333333507180214 T/ha
# 40) Predicted yield 1.4147515296936035 T/ha // Real yield 1.25 T/ha
# 41) Predicted yield 0.8700205087661743 T/ha // Real yield 1.0499999523162842 T/ha
# 42) Predicted yield 0.33364272117614746 T/ha // Real yield 0.4000000059604645 T/ha
# 43) Predicted yield 0.6716563105583191 T/ha // Real yield 1.5714285373687744 T/ha
# 44) Predicted yield 0.6940010786056519 T/ha // Real yield 0.75 T/ha
# 45) Predicted yield 0.4525185227394104 T/ha // Real yield 0.20000000298023224 T/ha
# 46) Predicted yield 0.5062042474746704 T/ha // Real yield 0.3125 T/ha
# 47) Predicted yield 0.49652227759361267 T/ha // Real yield 0.6000000238418579 T/ha
# 48) Predicted yield 0.5151367783546448 T/ha // Real yield 0.5333333611488342 T/ha
# 49) Predicted yield 0.8395566940307617 T/ha // Real yield 1.2000000476837158 T/ha
# 50) Predicted yield 0.06946612894535065 T/ha // Real yield 0.17499999701976776 T/ha
# 51) Predicted yield 0.6497315168380737 T/ha // Real yield 0.800000011920929 T/ha
# 52) Predicted yield 0.7264604568481445 T/ha // Real yield 0.5 T/ha
# 53) Predicted yield 0.6190574169158936 T/ha // Real yield 0.20000000298023224 T/ha
# 54) Predicted yield 0.36839160323143005 T/ha // Real yield 0.5 T/ha
# 55) Predicted yield 0.5122269988059998 T/ha // Real yield 0.699999988079071 T/ha
# 56) Predicted yield 0.6998268365859985 T/ha // Real yield 0.5 T/ha
# 57) Predicted yield 0.6696774363517761 T/ha // Real yield 0.6000000238418579 T/ha
# 58) Predicted yield 0.9315391182899475 T/ha // Real yield 1.0 T/ha
# 59) Predicted yield 0.9060314893722534 T/ha // Real yield 0.8999999761581421 T/ha
# 60) Predicted yield 0.07824024558067322 T/ha // Real yield 0.01666666753590107 T/ha
# 61) Predicted yield 0.8208643198013306 T/ha // Real yield 1.0 T/ha
# 62) Predicted yield 0.26479780673980713 T/ha // Real yield 0.20000000298023224 T/ha
# 63) Predicted yield 0.4684174954891205 T/ha // Real yield 0.30000001192092896 T/ha
# 64) Predicted yield 0.3658532500267029 T/ha // Real yield 0.0012499999720603228 T/ha
# 65) Predicted yield 0.6249483823776245 T/ha // Real yield 0.26249998807907104 T/ha
# 66) Predicted yield 0.49771296977996826 T/ha // Real yield 0.2916666567325592 T/ha
# 67) Predicted yield 0.6100881099700928 T/ha // Real yield 0.5 T/ha
# 68) Predicted yield 0.3000723123550415 T/ha // Real yield 0.30000001192092896 T/ha
# 69) Predicted yield 0.7210286259651184 T/ha // Real yield 0.30000001192092896 T/ha
# 70) Predicted yield 0.3691270053386688 T/ha // Real yield 0.44999998807907104 T/ha
# 71) Predicted yield 0.44453832507133484 T/ha // Real yield 0.5 T/ha
# 72) Predicted yield 0.4280111491680145 T/ha // Real yield 0.699999988079071 T/ha
# 73) Predicted yield 0.3892412483692169 T/ha // Real yield 0.5 T/ha
# 74) Predicted yield 0.36213377118110657 T/ha // Real yield 0.1666666716337204 T/ha
# 75) Predicted yield 0.025874711573123932 T/ha // Real yield 0.30000001192092896 T/ha
# 76) Predicted yield 0.3728998601436615 T/ha // Real yield 0.23333333432674408 T/ha
# 77) Predicted yield 0.9029074907302856 T/ha // Real yield 2.0 T/ha
# 78) Predicted yield 0.41381776332855225 T/ha // Real yield 0.6000000238418579 T/ha
# 79) Predicted yield 0.46529632806777954 T/ha // Real yield 0.15000000596046448 T/ha
# 80) Predicted yield 0.6252602934837341 T/ha // Real yield 0.23333333432674408 T/ha
# 81) Predicted yield 0.17565840482711792 T/ha // Real yield 0.05000000074505806 T/ha
# 82) Predicted yield 0.3439534604549408 T/ha // Real yield 0.44999998807907104 T/ha
# 83) Predicted yield 0.6608607769012451 T/ha // Real yield 0.375 T/ha
# 84) Predicted yield 1.5587401390075684 T/ha // Real yield 1.0 T/ha
# 85) Predicted yield 0.9598134160041809 T/ha // Real yield 1.0 T/ha
# 86) Predicted yield 0.223876953125 T/ha // Real yield 0.6000000238418579 T/ha
# 87) Predicted yield 1.0195839405059814 T/ha // Real yield 0.800000011920929 T/ha
# 88) Predicted yield 0.5439197421073914 T/ha // Real yield 0.41999998688697815 T/ha
# 89) Predicted yield 0.353207528591156 T/ha // Real yield 0.800000011920929 T/ha
# 90) Predicted yield 0.5737175345420837 T/ha // Real yield 0.625 T/ha
# 91) Predicted yield 0.035325005650520325 T/ha // Real yield 0.1666666716337204 T/ha
# 92) Predicted yield 0.5861358046531677 T/ha // Real yield 0.6000000238418579 T/ha
# 93) Predicted yield 0.3130214512348175 T/ha // Real yield 1.5 T/ha
# 94) Predicted yield 0.47121763229370117 T/ha // Real yield 0.47999998927116394 T/ha
# 95) Predicted yield 0.8474958539009094 T/ha // Real yield 0.800000011920929 T/ha
# 96) Predicted yield 0.8944314122200012 T/ha // Real yield 2.0 T/ha
# 97) Predicted yield 0.5594342350959778 T/ha // Real yield 0.4000000059604645 T/ha
# 98) Predicted yield 0.8137025833129883 T/ha // Real yield 1.1111111640930176 T/ha
# 99) Predicted yield 0.34971484541893005 T/ha // Real yield 0.25 T/ha
# 100) Predicted yield 0.22101861238479614 T/ha // Real yield 0.10000000149011612 T/ha
# 101) Predicted yield 0.6665241122245789 T/ha // Real yield 1.100000023841858 T/ha
# 102) Predicted yield 0.36692726612091064 T/ha // Real yield 0.6000000238418579 T/ha
# 103) Predicted yield 1.2708683013916016 T/ha // Real yield 2.0 T/ha
# 104) Predicted yield 0.022606253623962402 T/ha // Real yield 0.15789473056793213 T/ha
# 105) Predicted yield 0.6026812195777893 T/ha // Real yield 1.25 T/ha
# 106) Predicted yield 0.17074830830097198 T/ha // Real yield 0.10000000149011612 T/ha
# 107) Predicted yield 0.25775426626205444 T/ha // Real yield 0.004000000189989805 T/ha
# 108) Predicted yield 0.7178298830986023 T/ha // Real yield 0.47999998927116394 T/ha
# 109) Predicted yield 0.5687901973724365 T/ha // Real yield 0.4000000059604645 T/ha
# 110) Predicted yield 0.9165799617767334 T/ha // Real yield 0.4000000059604645 T/ha
# 111) Predicted yield 0.39981454610824585 T/ha // Real yield 0.14000000059604645 T/ha
# 112) Predicted yield 0.5853899717330933 T/ha // Real yield 0.5 T/ha
# 113) Predicted yield 0.5672222375869751 T/ha // Real yield 0.6499999761581421 T/ha
# 114) Predicted yield 0.8062475919723511 T/ha // Real yield 0.75 T/ha
# 115) Predicted yield 0.5790150165557861 T/ha // Real yield 0.5 T/ha
# 116) Predicted yield 0.7422178983688354 T/ha // Real yield 0.5 T/ha
# 117) Predicted yield 0.5622317790985107 T/ha // Real yield 0.44999998807907104 T/ha
# 118) Predicted yield 0.47454971075057983 T/ha // Real yield 0.4000000059604645 T/ha
# 119) Predicted yield 0.3630165755748749 T/ha // Real yield 0.4000000059604645 T/ha
# 120) Predicted yield 0.6443787217140198 T/ha // Real yield 0.6666666865348816 T/ha
# 121) Predicted yield 0.42315369844436646 T/ha // Real yield 0.15000000596046448 T/ha
# 122) Predicted yield 0.658266007900238 T/ha // Real yield 0.75 T/ha
# 123) Predicted yield 0.34064042568206787 T/ha // Real yield 0.14000000059604645 T/ha
# 124) Predicted yield 0.6079992651939392 T/ha // Real yield 0.33149999380111694 T/ha
# 125) Predicted yield 0.49787697196006775 T/ha // Real yield 0.07692307978868484 T/ha
# 126) Predicted yield 0.10621245950460434 T/ha // Real yield 0.10000000149011612 T/ha
# 127) Predicted yield 1.3752474784851074 T/ha // Real yield 0.800000011920929 T/ha
# 128) Predicted yield 0.8513108491897583 T/ha // Real yield 0.800000011920929 T/ha
# 129) Predicted yield 0.8032824397087097 T/ha // Real yield 1.0 T/ha
# 130) Predicted yield 0.507028341293335 T/ha // Real yield 1.100000023841858 T/ha
# 131) Predicted yield 0.5124223828315735 T/ha // Real yield 0.375 T/ha
# 132) Predicted yield 0.15860407054424286 T/ha // Real yield 0.10000000149011612 T/ha
# 133) Predicted yield 0.537347674369812 T/ha // Real yield 0.15000000596046448 T/ha
# 134) Predicted yield 0.3636794686317444 T/ha // Real yield 0.375 T/ha
# 135) Predicted yield 0.24928034842014313 T/ha // Real yield 0.800000011920929 T/ha
# 136) Predicted yield 0.5585083961486816 T/ha // Real yield 0.30000001192092896 T/ha
# 137) Predicted yield 0.39928391575813293 T/ha // Real yield 0.1666666716337204 T/ha
# 138) Predicted yield 0.30276796221733093 T/ha // Real yield 0.13333334028720856 T/ha
# 139) Predicted yield 0.6296112537384033 T/ha // Real yield 0.4000000059604645 T/ha
# 140) Predicted yield 0.7044618129730225 T/ha // Real yield 0.8500000238418579 T/ha
# 141) Predicted yield 0.32281869649887085 T/ha // Real yield 0.15000000596046448 T/ha
# 142) Predicted yield 0.24574480950832367 T/ha // Real yield 0.029999999329447746 T/ha
# 143) Predicted yield 0.4889114201068878 T/ha // Real yield 0.6000000238418579 T/ha
# 144) Predicted yield 0.8303737640380859 T/ha // Real yield 0.949999988079071 T/ha
# 145) Predicted yield 0.7159952521324158 T/ha // Real yield 0.625 T/ha
# 146) Predicted yield 0.3790278434753418 T/ha // Real yield 0.30000001192092896 T/ha
# 147) Predicted yield 0.7184489369392395 T/ha // Real yield 0.5 T/ha
# 148) Predicted yield 0.8857572078704834 T/ha // Real yield 0.8799999952316284 T/ha
# 149) Predicted yield 1.0677231550216675 T/ha // Real yield 0.9333333373069763 T/ha
# 150) Predicted yield 0.24692167341709137 T/ha // Real yield 0.3333333432674408 T/ha
# 151) Predicted yield 0.6672040820121765 T/ha // Real yield 0.75 T/ha
# 152) Predicted yield 0.8573229908943176 T/ha // Real yield 2.5 T/ha
# 153) Predicted yield 0.8854681253433228 T/ha // Real yield 0.8500000238418579 T/ha
# 154) Predicted yield 1.6112332344055176 T/ha // Real yield 0.75 T/ha
# 155) Predicted yield 1.190271258354187 T/ha // Real yield 0.5333333611488342 T/ha
# 156) Predicted yield -0.026137322187423706 T/ha // Real yield 0.12999999523162842 T/ha
# 157) Predicted yield 0.63917475938797 T/ha // Real yield 0.6228571534156799 T/ha
# 158) Predicted yield 16.31171417236328 T/ha // Real yield 16.0 T/ha
# 159) Predicted yield 0.22013773024082184 T/ha // Real yield 0.024000000208616257 T/ha
# 160) Predicted yield 0.454422265291214 T/ha // Real yield 0.6000000238418579 T/ha
# 161) Predicted yield 0.2735755145549774 T/ha // Real yield 0.02500000037252903 T/ha
# 162) Predicted yield 0.2701062262058258 T/ha // Real yield 0.07500000298023224 T/ha
# 163) Predicted yield 0.4754473865032196 T/ha // Real yield 0.625 T/ha
# 164) Predicted yield 0.801237940788269 T/ha // Real yield 1.0 T/ha
# 165) Predicted yield 0.7300986647605896 T/ha // Real yield 0.75 T/ha
# 166) Predicted yield 0.3545416593551636 T/ha // Real yield 0.05000000074505806 T/ha
# 167) Predicted yield 0.7407957315444946 T/ha // Real yield 0.8999999761581421 T/ha
# 168) Predicted yield 0.822154700756073 T/ha // Real yield 0.5 T/ha
# 169) Predicted yield 0.6489396095275879 T/ha // Real yield 0.4000000059604645 T/ha
# 170) Predicted yield 0.979282796382904 T/ha // Real yield 1.350000023841858 T/ha
# 171) Predicted yield 0.33778995275497437 T/ha // Real yield 0.0013333333190530539 T/ha
# 172) Predicted yield 0.34002685546875 T/ha // Real yield 1.1111111640930176 T/ha
# 173) Predicted yield 0.5588838458061218 T/ha // Real yield 0.20000000298023224 T/ha
# 174) Predicted yield 0.11673518270254135 T/ha // Real yield 0.10000000149011612 T/ha
# 175) Predicted yield 0.06683383136987686 T/ha // Real yield 0.10000000149011612 T/ha
# 176) Predicted yield 0.18162478506565094 T/ha // Real yield 0.25 T/ha
# 177) Predicted yield 0.5302311778068542 T/ha // Real yield 0.5 T/ha
# 178) Predicted yield 0.5666986703872681 T/ha // Real yield 1.0 T/ha
# 179) Predicted yield 0.5910873413085938 T/ha // Real yield 0.75 T/ha
# 180) Predicted yield 0.7535756230354309 T/ha // Real yield 0.5 T/ha
# 181) Predicted yield 0.19183482229709625 T/ha // Real yield 0.125 T/ha
# 182) Predicted yield 0.4353102743625641 T/ha // Real yield 0.23333333432674408 T/ha
# 183) Predicted yield 0.354937344789505 T/ha // Real yield 0.3199999928474426 T/ha
# 184) Predicted yield 0.36823758482933044 T/ha // Real yield 0.3461538553237915 T/ha
# 185) Predicted yield 0.5389525890350342 T/ha // Real yield 0.15000000596046448 T/ha
# 186) Predicted yield 0.30062592029571533 T/ha // Real yield 0.22499999403953552 T/ha
# 187) Predicted yield 0.6977384090423584 T/ha // Real yield 0.5 T/ha
# 188) Predicted yield 0.3115426003932953 T/ha // Real yield 0.6666666865348816 T/ha
# 189) Predicted yield 0.6627572178840637 T/ha // Real yield 0.05000000074505806 T/ha
# 190) Predicted yield 0.5838038921356201 T/ha // Real yield 0.6666666865348816 T/ha
# 191) Predicted yield 0.7553983330726624 T/ha // Real yield 0.20000000298023224 T/ha
# 192) Predicted yield 0.9277216792106628 T/ha // Real yield 0.800000011920929 T/ha
# 193) Predicted yield 0.3890085816383362 T/ha // Real yield 0.8399999737739563 T/ha
# 194) Predicted yield 0.7045987248420715 T/ha // Real yield 0.44999998807907104 T/ha
# 195) Predicted yield 0.6008970737457275 T/ha // Real yield 0.5 T/ha
# 196) Predicted yield 0.9380490779876709 T/ha // Real yield 0.5 T/ha
# 197) Predicted yield 0.6849792003631592 T/ha // Real yield 1.0 T/ha
# 198) Predicted yield 0.6098562479019165 T/ha // Real yield 0.44999998807907104 T/ha
# 199) Predicted yield 0.6754169464111328 T/ha // Real yield 0.5 T/ha
# 200) Predicted yield 0.5919824242591858 T/ha // Real yield 0.699999988079071 T/ha
# 201) Predicted yield 0.3347311019897461 T/ha // Real yield 0.375 T/ha
# 202) Predicted yield 0.5044556856155396 T/ha // Real yield 0.15000000596046448 T/ha
# 203) Predicted yield 0.5514925122261047 T/ha // Real yield 0.46666666865348816 T/ha
# 204) Predicted yield 0.33501315116882324 T/ha // Real yield 0.20000000298023224 T/ha
# 205) Predicted yield 0.4047355651855469 T/ha // Real yield 0.8571428656578064 T/ha
# 206) Predicted yield 0.4676836431026459 T/ha // Real yield 0.3636363744735718 T/ha
# 207) Predicted yield 1.590106725692749 T/ha // Real yield 1.875 T/ha
# 208) Predicted yield 0.49175629019737244 T/ha // Real yield 0.6000000238418579 T/ha
# 209) Predicted yield 0.24242250621318817 T/ha // Real yield 0.10000000149011612 T/ha
# 210) Predicted yield 0.587868869304657 T/ha // Real yield 0.75 T/ha
# 211) Predicted yield 0.6934166550636292 T/ha // Real yield 0.75 T/ha
# 212) Predicted yield 0.3730090260505676 T/ha // Real yield 0.10000000149011612 T/ha
# 213) Predicted yield 0.64696204662323 T/ha // Real yield 0.6666666865348816 T/ha
# 214) Predicted yield 0.20369821786880493 T/ha // Real yield 0.07999999821186066 T/ha
# 215) Predicted yield 0.4288695752620697 T/ha // Real yield 1.0 T/ha
# 216) Predicted yield 0.5155231356620789 T/ha // Real yield 1.2000000476837158 T/ha
# 217) Predicted yield 0.4510854184627533 T/ha // Real yield 0.5 T/ha
# 218) Predicted yield 0.4226464033126831 T/ha // Real yield 0.6666666865348816 T/ha
# 219) Predicted yield 0.3843814730644226 T/ha // Real yield 0.375 T/ha
# 220) Predicted yield 0.17894884943962097 T/ha // Real yield 0.05000000074505806 T/ha
# 221) Predicted yield 0.3964526355266571 T/ha // Real yield 0.10000000149011612 T/ha
# 222) Predicted yield 0.27193862199783325 T/ha // Real yield 0.06666667014360428 T/ha
# 223) Predicted yield 0.6675997376441956 T/ha // Real yield 0.8999999761581421 T/ha
# 224) Predicted yield 0.20526331663131714 T/ha // Real yield 0.25 T/ha
# 225) Predicted yield 0.6009392142295837 T/ha // Real yield 0.36000001430511475 T/ha
# 226) Predicted yield 0.42441076040267944 T/ha // Real yield 0.6333333253860474 T/ha
# 227) Predicted yield 1.0722784996032715 T/ha // Real yield 0.8999999761581421 T/ha
# 228) Predicted yield 0.33877599239349365 T/ha // Real yield 0.25 T/ha
# 229) Predicted yield 0.44246089458465576 T/ha // Real yield 0.21666666865348816 T/ha
# 230) Predicted yield 1.0119777917861938 T/ha // Real yield 0.32499998807907104 T/ha
# 231) Predicted yield 0.9362380504608154 T/ha // Real yield 1.0 T/ha
# 232) Predicted yield 0.7025444507598877 T/ha // Real yield 0.800000011920929 T/ha
# 233) Predicted yield 0.5436463952064514 T/ha // Real yield 0.75 T/ha
# 234) Predicted yield 0.6772395968437195 T/ha // Real yield 0.800000011920929 T/ha
# 235) Predicted yield 0.8150901198387146 T/ha // Real yield 0.699999988079071 T/ha
# 236) Predicted yield 0.340703547000885 T/ha // Real yield 0.5 T/ha
# 237) Predicted yield 0.4403999447822571 T/ha // Real yield 0.11538461595773697 T/ha
# 238) Predicted yield 0.47447454929351807 T/ha // Real yield 0.5 T/ha
# 239) Predicted yield 0.21823562681674957 T/ha // Real yield 0.10000000149011612 T/ha
# 240) Predicted yield 0.21541732549667358 T/ha // Real yield 0.03999999910593033 T/ha
# 241) Predicted yield 0.6244798302650452 T/ha // Real yield 1.2000000476837158 T/ha
# 242) Predicted yield 0.36431756615638733 T/ha // Real yield 0.7200000286102295 T/ha
# 243) Predicted yield 0.31331220269203186 T/ha // Real yield 0.32499998807907104 T/ha
# 244) Predicted yield 0.7592427730560303 T/ha // Real yield 1.0 T/ha
# 245) Predicted yield 0.3750952482223511 T/ha // Real yield 0.13636364042758942 T/ha
# 246) Predicted yield 0.7200638651847839 T/ha // Real yield 0.5 T/ha
# 247) Predicted yield 0.7603838443756104 T/ha // Real yield 0.6666666865348816 T/ha
# 248) Predicted yield 0.5686328411102295 T/ha // Real yield 1.100000023841858 T/ha
# 249) Predicted yield 14.31671142578125 T/ha // Real yield 15.0 T/ha
# 250) Predicted yield 0.3856731951236725 T/ha // Real yield 0.07500000298023224 T/ha
# 251) Predicted yield 0.6474810242652893 T/ha // Real yield 0.25 T/ha
# 252) Predicted yield 0.5505019426345825 T/ha // Real yield 0.375 T/ha
# 253) Predicted yield 0.809350311756134 T/ha // Real yield 1.0 T/ha
# 254) Predicted yield 0.5884081721305847 T/ha // Real yield 0.25 T/ha
# 255) Predicted yield 0.986072301864624 T/ha // Real yield 0.44999998807907104 T/ha
# 256) Predicted yield 0.903748631477356 T/ha // Real yield 0.75 T/ha
# 257) Predicted yield 0.7458646297454834 T/ha // Real yield 0.949999988079071 T/ha
# 258) Predicted yield 0.4162599444389343 T/ha // Real yield 1.0 T/ha
# 259) Predicted yield 0.1898455172777176 T/ha // Real yield 0.11249999701976776 T/ha
# 260) Predicted yield 0.6451399922370911 T/ha // Real yield 0.5 T/ha
# 261) Predicted yield 0.37985336780548096 T/ha // Real yield 0.20000000298023224 T/ha
# 262) Predicted yield 0.2851470708847046 T/ha // Real yield 0.02500000037252903 T/ha
# 263) Predicted yield 0.24380281567573547 T/ha // Real yield 0.15555556118488312 T/ha
# 264) Predicted yield 0.8960492014884949 T/ha // Real yield 0.11249999701976776 T/ha
# 265) Predicted yield 0.8856537342071533 T/ha // Real yield 0.800000011920929 T/ha
# 266) Predicted yield 0.10764721035957336 T/ha // Real yield 0.05000000074505806 T/ha
# 267) Predicted yield 0.32007598876953125 T/ha // Real yield 0.19499999284744263 T/ha
# 268) Predicted yield 0.40185433626174927 T/ha // Real yield 0.25 T/ha
# 269) Predicted yield 0.5716124176979065 T/ha // Real yield 0.5625 T/ha
# 270) Predicted yield 0.465823769569397 T/ha // Real yield 0.36000001430511475 T/ha
# 271) Predicted yield 0.15743488073349 T/ha // Real yield 0.20000000298023224 T/ha
# 272) Predicted yield 1.1547502279281616 T/ha // Real yield 1.600000023841858 T/ha
# 273) Predicted yield 0.4918297231197357 T/ha // Real yield 0.17499999701976776 T/ha
# 274) Predicted yield 0.8807064294815063 T/ha // Real yield 0.8999999761581421 T/ha
# 275) Predicted yield 0.6174428462982178 T/ha // Real yield 0.44999998807907104 T/ha
# 276) Predicted yield 0.24433954060077667 T/ha // Real yield 0.15000000596046448 T/ha
# 277) Predicted yield 0.4572068452835083 T/ha // Real yield 0.25 T/ha
# 278) Predicted yield 6.282648086547852 T/ha // Real yield 6.666666507720947 T/ha
# 279) Predicted yield 0.2803530693054199 T/ha // Real yield 0.02500000037252903 T/ha
# 280) Predicted yield 0.3581859767436981 T/ha // Real yield 0.4285714328289032 T/ha
# 281) Predicted yield 0.457550048828125 T/ha // Real yield 0.000699999975040555 T/ha
# 282) Predicted yield 0.23992013931274414 T/ha // Real yield 0.07000000029802322 T/ha
# 283) Predicted yield 0.1457238793373108 T/ha // Real yield 0.10000000149011612 T/ha
# 284) Predicted yield 0.06083451211452484 T/ha // Real yield 0.07500000298023224 T/ha
# 285) Predicted yield 1.11630117893219 T/ha // Real yield 1.5 T/ha
# 286) Predicted yield 0.5984856486320496 T/ha // Real yield 0.800000011920929 T/ha
# 287) Predicted yield 0.6517292857170105 T/ha // Real yield 1.0 T/ha
# 288) Predicted yield 0.6116681694984436 T/ha // Real yield 0.699999988079071 T/ha
# 289) Predicted yield 0.36664313077926636 T/ha // Real yield 0.1666666716337204 T/ha
# 290) Predicted yield 0.6608312726020813 T/ha // Real yield 1.5 T/ha
# 291) Predicted yield 0.13279323279857635 T/ha // Real yield 0.3333333432674408 T/ha
# 292) Predicted yield 2.7520668506622314 T/ha // Real yield 0.08749999850988388 T/ha
# 293) Predicted yield 0.41188085079193115 T/ha // Real yield 0.5 T/ha
# 294) Predicted yield 0.7134054899215698 T/ha // Real yield 0.3199999928474426 T/ha
# 295) Predicted yield 0.6990871429443359 T/ha // Real yield 0.4000000059604645 T/ha
# 296) Predicted yield 0.5689848065376282 T/ha // Real yield 0.30000001192092896 T/ha
# 297) Predicted yield 0.4835626780986786 T/ha // Real yield 0.5 T/ha
# 298) Predicted yield 0.3735594153404236 T/ha // Real yield 0.40799999237060547 T/ha
# 299) Predicted yield 0.42525094747543335 T/ha // Real yield 0.5666666626930237 T/ha
# 300) Predicted yield 0.5621917247772217 T/ha // Real yield 0.2879999876022339 T/ha
# 301) Predicted yield 0.3207137882709503 T/ha // Real yield 0.4000000059604645 T/ha
# 302) Predicted yield 0.5593486428260803 T/ha // Real yield 0.699999988079071 T/ha
# 303) Predicted yield 0.2819018065929413 T/ha // Real yield 0.20000000298023224 T/ha
# 304) Predicted yield 0.34073424339294434 T/ha // Real yield 0.6000000238418579 T/ha
# 305) Predicted yield 1.105790615081787 T/ha // Real yield 0.9375 T/ha
# 306) Predicted yield 0.9525454640388489 T/ha // Real yield 1.75 T/ha
# 307) Predicted yield 0.5712565183639526 T/ha // Real yield 0.6000000238418579 T/ha
# 308) Predicted yield 0.5996475219726562 T/ha // Real yield 0.5333333611488342 T/ha
# 309) Predicted yield 0.6686934232711792 T/ha // Real yield 0.5 T/ha
# 310) Predicted yield 0.27605974674224854 T/ha // Real yield 0.10000000149011612 T/ha
# 311) Predicted yield 0.4933234453201294 T/ha // Real yield 0.30000001192092896 T/ha
# 312) Predicted yield 0.21382170915603638 T/ha // Real yield 0.5 T/ha
# 313) Predicted yield 0.13672688603401184 T/ha // Real yield 0.10000000149011612 T/ha
# 314) Predicted yield 0.6854732632637024 T/ha // Real yield 0.6666666865348816 T/ha
# 315) Predicted yield 0.32522809505462646 T/ha // Real yield 0.6499999761581421 T/ha
# 316) Predicted yield 0.7930139899253845 T/ha // Real yield 0.7400000095367432 T/ha
# 317) Predicted yield 1.0676994323730469 T/ha // Real yield 1.2000000476837158 T/ha
# 318) Predicted yield 0.3149479627609253 T/ha // Real yield 0.30000001192092896 T/ha
# 319) Predicted yield 0.5002768039703369 T/ha // Real yield 0.3199999928474426 T/ha
# 320) Predicted yield 0.25967565178871155 T/ha // Real yield 0.30000001192092896 T/ha
# 321) Predicted yield 0.5160310864448547 T/ha // Real yield 0.25 T/ha
# 322) Predicted yield 0.5691232681274414 T/ha // Real yield 1.0 T/ha
# 323) Predicted yield 0.7561401724815369 T/ha // Real yield 1.0 T/ha
# 324) Predicted yield 0.3958078920841217 T/ha // Real yield 0.00039999998989515007 T/ha
# 325) Predicted yield 0.374627947807312 T/ha // Real yield 0.5714285969734192 T/ha
# 326) Predicted yield 0.5510782599449158 T/ha // Real yield 0.2666666805744171 T/ha
# 327) Predicted yield 0.8128039240837097 T/ha // Real yield 0.8571428656578064 T/ha
# 328) Predicted yield 0.9214496612548828 T/ha // Real yield 0.949999988079071 T/ha
# 329) Predicted yield 0.4860154688358307 T/ha // Real yield 0.800000011920929 T/ha
# 330) Predicted yield 0.10580703616142273 T/ha // Real yield 0.15000000596046448 T/ha
# 331) Predicted yield 0.6820175647735596 T/ha // Real yield 0.6666666865348816 T/ha
# 332) Predicted yield 0.9348800182342529 T/ha // Real yield 0.125 T/ha
# 333) Predicted yield 0.22486154735088348 T/ha // Real yield 0.0555555559694767 T/ha
# 334) Predicted yield 0.9009606838226318 T/ha // Real yield 1.0 T/ha
# 335) Predicted yield 0.9630683064460754 T/ha // Real yield 0.30000001192092896 T/ha
# 336) Predicted yield 0.5940413475036621 T/ha // Real yield 0.4000000059604645 T/ha
# 337) Predicted yield 0.8779385685920715 T/ha // Real yield 0.699999988079071 T/ha
# 338) Predicted yield 1.1546719074249268 T/ha // Real yield 1.2000000476837158 T/ha
# 339) Predicted yield 0.44516098499298096 T/ha // Real yield 0.06666667014360428 T/ha
# 340) Predicted yield 0.3900964558124542 T/ha // Real yield 1.0 T/ha
# 341) Predicted yield 0.8091036677360535 T/ha // Real yield 1.0 T/ha
# 342) Predicted yield 0.4866067171096802 T/ha // Real yield 0.15000000596046448 T/ha
# 343) Predicted yield 0.53791743516922 T/ha // Real yield 0.3333333432674408 T/ha
# 344) Predicted yield 0.8142308592796326 T/ha // Real yield 1.0 T/ha
# 345) Predicted yield 0.4004257619380951 T/ha // Real yield 0.44999998807907104 T/ha
# 346) Predicted yield 0.6436006426811218 T/ha // Real yield 0.20000000298023224 T/ha
# 347) Predicted yield 0.34793347120285034 T/ha // Real yield 0.5 T/ha
# 348) Predicted yield 0.5376174449920654 T/ha // Real yield 0.699999988079071 T/ha
# 349) Predicted yield 4.488705635070801 T/ha // Real yield 4.0 T/ha
# 350) Predicted yield 0.5393378138542175 T/ha // Real yield 0.7333333492279053 T/ha
# 351) Predicted yield 1.1340913772583008 T/ha // Real yield 1.2000000476837158 T/ha
# 352) Predicted yield 0.7693253755569458 T/ha // Real yield 0.6666666865348816 T/ha
# 353) Predicted yield 0.6473057866096497 T/ha // Real yield 0.5 T/ha
# 354) Predicted yield 0.5278002619743347 T/ha // Real yield 0.4000000059604645 T/ha
# 355) Predicted yield 0.7463287711143494 T/ha // Real yield 1.0 T/ha
# 356) Predicted yield 1.0217045545578003 T/ha // Real yield 0.30000001192092896 T/ha
# 357) Predicted yield 0.7423931360244751 T/ha // Real yield 0.2666666805744171 T/ha
# 358) Predicted yield 0.7211596369743347 T/ha // Real yield 0.4444444477558136 T/ha
# 359) Predicted yield 0.9688124060630798 T/ha // Real yield 0.5 T/ha
# 360) Predicted yield 0.4425550699234009 T/ha // Real yield 0.25 T/ha
# 361) Predicted yield 0.5265733003616333 T/ha // Real yield 0.20000000298023224 T/ha
# 362) Predicted yield 0.513007402420044 T/ha // Real yield 0.3199999928474426 T/ha
# 363) Predicted yield 0.3714631497859955 T/ha // Real yield 0.10833333432674408 T/ha
# 364) Predicted yield 0.23200365900993347 T/ha // Real yield 0.0033333334140479565 T/ha
# 365) Predicted yield 0.532953143119812 T/ha // Real yield 0.22499999403953552 T/ha
# 366) Predicted yield 0.4647800624370575 T/ha // Real yield 1.0 T/ha
# 367) Predicted yield 0.5918056964874268 T/ha // Real yield 0.4000000059604645 T/ha
# 368) Predicted yield 0.5053475499153137 T/ha // Real yield 0.7200000286102295 T/ha
# 369) Predicted yield 0.41057607531547546 T/ha // Real yield 0.1875 T/ha
# 370) Predicted yield 0.9461075663566589 T/ha // Real yield 0.5 T/ha
# 371) Predicted yield 1.037909984588623 T/ha // Real yield 1.3333333730697632 T/ha
# 372) Predicted yield 0.718881368637085 T/ha // Real yield 0.125 T/ha
# 373) Predicted yield 0.8082429766654968 T/ha // Real yield 0.6666666865348816 T/ha
# 374) Predicted yield 0.5750553607940674 T/ha // Real yield 0.20916666090488434 T/ha
# 375) Predicted yield 0.5627268552780151 T/ha // Real yield 0.20000000298023224 T/ha
# 376) Predicted yield 0.515996515750885 T/ha // Real yield 0.5666666626930237 T/ha
# 377) Predicted yield 0.3698764145374298 T/ha // Real yield 0.17499999701976776 T/ha
# 378) Predicted yield 0.927240252494812 T/ha // Real yield 0.30000001192092896 T/ha
# 379) Predicted yield 0.5045387148857117 T/ha // Real yield 0.10000000149011612 T/ha
# 380) Predicted yield 0.2501424551010132 T/ha // Real yield 0.30000001192092896 T/ha
# 381) Predicted yield 0.39819538593292236 T/ha // Real yield 0.6000000238418579 T/ha
# 382) Predicted yield 0.5189477801322937 T/ha // Real yield 0.5 T/ha
# 383) Predicted yield 0.2680310904979706 T/ha // Real yield 0.30000001192092896 T/ha
# 384) Predicted yield 0.45410823822021484 T/ha // Real yield 0.6499999761581421 T/ha
# 385) Predicted yield 0.5108199119567871 T/ha // Real yield 0.20000000298023224 T/ha
# 386) Predicted yield 0.04519402235746384 T/ha // Real yield 0.06666667014360428 T/ha
# 387) Predicted yield 0.7144467830657959 T/ha // Real yield 0.6000000238418579 T/ha
# 388) Predicted yield 0.5696743726730347 T/ha // Real yield 0.46666666865348816 T/ha
# 389) Predicted yield 0.4940868020057678 T/ha // Real yield 0.25 T/ha
# 390) Predicted yield 0.2687981128692627 T/ha // Real yield 0.30000001192092896 T/ha
# 391) Predicted yield 0.6134060025215149 T/ha // Real yield 1.0 T/ha
# 392) Predicted yield 0.3572649657726288 T/ha // Real yield 0.15000000596046448 T/ha
# 393) Predicted yield 0.7094972729682922 T/ha // Real yield 0.4399999976158142 T/ha
# 394) Predicted yield 0.8013155460357666 T/ha // Real yield 1.0199999809265137 T/ha
# 395) Predicted yield 1.1377756595611572 T/ha // Real yield 1.4333332777023315 T/ha
# 396) Predicted yield 0.4333529472351074 T/ha // Real yield 0.8666666746139526 T/ha
# 397) Predicted yield 0.6475350260734558 T/ha // Real yield 1.0 T/ha
# 398) Predicted yield 0.6786053776741028 T/ha // Real yield 0.75 T/ha
# 399) Predicted yield 1.5617114305496216 T/ha // Real yield 2.25 T/ha
# 400) Predicted yield 0.5600268244743347 T/ha // Real yield 0.46666666865348816 T/ha
# 401) Predicted yield 0.24973739683628082 T/ha // Real yield 0.4000000059604645 T/ha
# 402) Predicted yield 0.5989902019500732 T/ha // Real yield 0.46666666865348816 T/ha
# 403) Predicted yield 0.40615975856781006 T/ha // Real yield 0.11428571492433548 T/ha
# 404) Predicted yield 1.3098547458648682 T/ha // Real yield 1.5 T/ha
# 405) Predicted yield 1.162355899810791 T/ha // Real yield 0.3499999940395355 T/ha
# 406) Predicted yield 0.5763380527496338 T/ha // Real yield 0.3333333432674408 T/ha
# 407) Predicted yield 0.5098345279693604 T/ha // Real yield 0.20000000298023224 T/ha
# 408) Predicted yield 0.313268780708313 T/ha // Real yield 0.44999998807907104 T/ha
# 409) Predicted yield 0.4673428535461426 T/ha // Real yield 0.4000000059604645 T/ha
# 410) Predicted yield 0.5024701952934265 T/ha // Real yield 0.5 T/ha
# 411) Predicted yield 0.6511771082878113 T/ha // Real yield 0.5 T/ha
# 412) Predicted yield -0.12880803644657135 T/ha // Real yield 0.05000000074505806 T/ha
# 413) Predicted yield 0.8334238529205322 T/ha // Real yield 0.6800000071525574 T/ha
# 414) Predicted yield 0.9566366672515869 T/ha // Real yield 1.0800000429153442 T/ha
# 415) Predicted yield 0.4489234387874603 T/ha // Real yield 0.15000000596046448 T/ha
# 416) Predicted yield 0.5390671491622925 T/ha // Real yield 0.2083333283662796 T/ha
# 417) Predicted yield 0.45734813809394836 T/ha // Real yield 0.10000000149011612 T/ha
# 418) Predicted yield 0.5560190081596375 T/ha // Real yield 0.15000000596046448 T/ha
# 419) Predicted yield 0.3419419825077057 T/ha // Real yield 0.10000000149011612 T/ha
# 420) Predicted yield 0.5456440448760986 T/ha // Real yield 0.20000000298023224 T/ha
# 421) Predicted yield 0.6224170327186584 T/ha // Real yield 0.20000000298023224 T/ha
# 422) Predicted yield 0.8209244012832642 T/ha // Real yield 0.13333334028720856 T/ha
# 423) Predicted yield 0.43680548667907715 T/ha // Real yield 0.05249999836087227 T/ha
# 424) Predicted yield 0.6010922789573669 T/ha // Real yield 0.23333333432674408 T/ha
# 425) Predicted yield 0.465975821018219 T/ha // Real yield 0.20000000298023224 T/ha
# 426) Predicted yield 0.2657243311405182 T/ha // Real yield 0.25 T/ha
# 427) Predicted yield 0.9452577233314514 T/ha // Real yield 0.5 T/ha
# 428) Predicted yield 0.8950117826461792 T/ha // Real yield 0.699999988079071 T/ha
# 429) Predicted yield 0.8610382080078125 T/ha // Real yield 0.6600000262260437 T/ha
# 430) Predicted yield 0.30829036235809326 T/ha // Real yield 0.5909090638160706 T/ha
# 431) Predicted yield 0.3435570299625397 T/ha // Real yield 0.36000001430511475 T/ha
# 432) Predicted yield 0.4571080207824707 T/ha // Real yield 0.5 T/ha
# 433) Predicted yield 0.614311695098877 T/ha // Real yield 0.3333333432674408 T/ha
# 434) Predicted yield 0.5275108814239502 T/ha // Real yield 0.24285714328289032 T/ha
# 435) Predicted yield 0.3696984052658081 T/ha // Real yield 0.6000000238418579 T/ha
# 436) Predicted yield 0.3711288869380951 T/ha // Real yield 0.06666667014360428 T/ha
# 437) Predicted yield 0.8423280119895935 T/ha // Real yield 0.4000000059604645 T/ha
# 438) Predicted yield 0.7349967956542969 T/ha // Real yield 0.44999998807907104 T/ha
# 439) Predicted yield 0.5089412331581116 T/ha // Real yield 0.2666666805744171 T/ha
# 440) Predicted yield 1.263643741607666 T/ha // Real yield 0.800000011920929 T/ha
# 441) Predicted yield 0.39540430903434753 T/ha // Real yield 0.3333333432674408 T/ha
# 442) Predicted yield 1.1721068620681763 T/ha // Real yield 0.30000001192092896 T/ha
# 443) Predicted yield 0.5283815264701843 T/ha // Real yield 0.3333333432674408 T/ha
# 444) Predicted yield 0.2526918351650238 T/ha // Real yield 0.30000001192092896 T/ha
# 445) Predicted yield 0.5529968738555908 T/ha // Real yield 0.4545454680919647 T/ha
# 446) Predicted yield 0.6347274780273438 T/ha // Real yield 0.25 T/ha
# 447) Predicted yield 0.6976494193077087 T/ha // Real yield 0.125 T/ha
# 448) Predicted yield 0.17550648748874664 T/ha // Real yield 0.33000001311302185 T/ha
# 449) Predicted yield 0.7869503498077393 T/ha // Real yield 0.5 T/ha
# 450) Predicted yield 0.37868279218673706 T/ha // Real yield 0.6000000238418579 T/ha
# 451) Predicted yield 0.7445912957191467 T/ha // Real yield 1.0 T/ha
# 452) Predicted yield 0.8757283091545105 T/ha // Real yield 0.6000000238418579 T/ha
# 453) Predicted yield 0.3615973889827728 T/ha // Real yield 0.4000000059604645 T/ha
# 454) Predicted yield 0.6659740209579468 T/ha // Real yield 0.75 T/ha
# 455) Predicted yield 0.793665885925293 T/ha // Real yield 0.10000000149011612 T/ha
# 456) Predicted yield 0.912984311580658 T/ha // Real yield 0.7250000238418579 T/ha
# 457) Predicted yield 1.1793688535690308 T/ha // Real yield 2.0 T/ha
# 458) Predicted yield 1.1588199138641357 T/ha // Real yield 0.949999988079071 T/ha
# 459) Predicted yield 0.5375070571899414 T/ha // Real yield 0.5 T/ha
# 460) Predicted yield 0.5302311778068542 T/ha // Real yield 0.02500000037252903 T/ha
# 461) Predicted yield 0.41329190135002136 T/ha // Real yield 0.30000001192092896 T/ha
# 462) Predicted yield 0.86308753490448 T/ha // Real yield 0.6000000238418579 T/ha
# 463) Predicted yield 0.9141966700553894 T/ha // Real yield 0.8333333134651184 T/ha
# 464) Predicted yield 0.5780102014541626 T/ha // Real yield 0.5 T/ha
# 465) Predicted yield 0.7828495502471924 T/ha // Real yield 0.3333333432674408 T/ha
# 466) Predicted yield 0.701798677444458 T/ha // Real yield 1.1333333253860474 T/ha
# 467) Predicted yield 0.6634836792945862 T/ha // Real yield 0.75 T/ha
# 468) Predicted yield 0.5970458984375 T/ha // Real yield 0.6666666865348816 T/ha
# 469) Predicted yield 0.5960273146629333 T/ha // Real yield 0.6000000238418579 T/ha
# 470) Predicted yield 0.710275411605835 T/ha // Real yield 0.949999988079071 T/ha
# 471) Predicted yield 0.7087081670761108 T/ha // Real yield 0.5 T/ha
# 472) Predicted yield 0.5087922811508179 T/ha // Real yield 0.44999998807907104 T/ha
# 473) Predicted yield 0.461398720741272 T/ha // Real yield 0.6666666865348816 T/ha
# 474) Predicted yield 0.6783739924430847 T/ha // Real yield 0.6000000238418579 T/ha
# 475) Predicted yield 0.5153954029083252 T/ha // Real yield 0.6000000238418579 T/ha
# 476) Predicted yield 0.4151264429092407 T/ha // Real yield 0.5333333611488342 T/ha
# 477) Predicted yield 0.49345412850379944 T/ha // Real yield 0.5333333611488342 T/ha
# 478) Predicted yield 0.7941571474075317 T/ha // Real yield 0.6000000238418579 T/ha
# 479) Predicted yield 0.6725587248802185 T/ha // Real yield 0.6666666865348816 T/ha
# 480) Predicted yield 0.4250697195529938 T/ha // Real yield 0.4000000059604645 T/ha
# 481) Predicted yield 0.3839353024959564 T/ha // Real yield 0.5285714268684387 T/ha
# 482) Predicted yield 0.4501296281814575 T/ha // Real yield 0.6000000238418579 T/ha
# 483) Predicted yield 0.7916719913482666 T/ha // Real yield 0.6000000238418579 T/ha
# 484) Predicted yield 0.9716377258300781 T/ha // Real yield 0.4000000059604645 T/ha
# 485) Predicted yield 0.5729265809059143 T/ha // Real yield 0.07500000298023224 T/ha
# 486) Predicted yield 1.0362902879714966 T/ha // Real yield 1.1666666269302368 T/ha
# 487) Predicted yield 0.8698022365570068 T/ha // Real yield 0.8999999761581421 T/ha
# 488) Predicted yield 0.6847582459449768 T/ha // Real yield 0.5 T/ha
# 489) Predicted yield 0.8499913811683655 T/ha // Real yield 0.5 T/ha
# 490) Predicted yield 0.7952352166175842 T/ha // Real yield 0.75 T/ha
# 491) Predicted yield 0.5864558815956116 T/ha // Real yield 0.47999998927116394 T/ha
# 492) Predicted yield 2.0859172344207764 T/ha // Real yield 0.30000001192092896 T/ha
# 493) Predicted yield 0.6236262917518616 T/ha // Real yield 0.41999998688697815 T/ha
# 494) Predicted yield 1.0640898942947388 T/ha // Real yield 0.699999988079071 T/ha
# 495) Predicted yield 0.9393634796142578 T/ha // Real yield 0.8500000238418579 T/ha
# 496) Predicted yield 0.7165278196334839 T/ha // Real yield 0.8999999761581421 T/ha
# 497) Predicted yield 0.4461818337440491 T/ha // Real yield 1.0 T/ha
# 498) Predicted yield 0.6415135264396667 T/ha // Real yield 1.399999976158142 T/ha
# 499) Predicted yield 0.3062180280685425 T/ha // Real yield 0.15000000596046448 T/ha
# 500) Predicted yield 0.30384519696235657 T/ha // Real yield 0.05000000074505806 T/ha
# 501) Predicted yield 0.619591474533081 T/ha // Real yield 0.75 T/ha
# 502) Predicted yield 0.6168166995048523 T/ha // Real yield 0.7333333492279053 T/ha
# 503) Predicted yield 0.4456023573875427 T/ha // Real yield 0.15000000596046448 T/ha
# 504) Predicted yield 0.485949844121933 T/ha // Real yield 0.8999999761581421 T/ha
# 505) Predicted yield 0.9016545414924622 T/ha // Real yield 0.699999988079071 T/ha
# 506) Predicted yield 0.34297168254852295 T/ha // Real yield 0.4000000059604645 T/ha
# 507) Predicted yield 0.8793222904205322 T/ha // Real yield 1.399999976158142 T/ha
# 508) Predicted yield 1.1307635307312012 T/ha // Real yield 1.3333333730697632 T/ha
# 509) Predicted yield 0.370581716299057 T/ha // Real yield 0.13333334028720856 T/ha
# 510) Predicted yield 0.3043190836906433 T/ha // Real yield 0.6000000238418579 T/ha
# 511) Predicted yield 0.860325038433075 T/ha // Real yield 0.5 T/ha
# 512) Predicted yield 0.6004116535186768 T/ha // Real yield 0.4000000059604645 T/ha
# 513) Predicted yield 0.43653202056884766 T/ha // Real yield 0.5 T/ha
# 514) Predicted yield 0.5862036347389221 T/ha // Real yield 0.5 T/ha
# 515) Predicted yield 0.6534302830696106 T/ha // Real yield 0.3199999928474426 T/ha
# 516) Predicted yield 0.16554373502731323 T/ha // Real yield 0.4000000059604645 T/ha
# 517) Predicted yield 0.8167922496795654 T/ha // Real yield 0.800000011920929 T/ha
# 518) Predicted yield 0.5450581908226013 T/ha // Real yield 0.6000000238418579 T/ha
# 519) Predicted yield 0.6570499539375305 T/ha // Real yield 0.5 T/ha
# 520) Predicted yield 0.6769915819168091 T/ha // Real yield 0.44999998807907104 T/ha
# 521) Predicted yield 0.7712871432304382 T/ha // Real yield 1.0 T/ha
# 522) Predicted yield 0.40821659564971924 T/ha // Real yield 0.5 T/ha
# 523) Predicted yield 0.84466952085495 T/ha // Real yield 1.3333333730697632 T/ha
# 524) Predicted yield 0.6500594615936279 T/ha // Real yield 0.44999998807907104 T/ha
# 525) Predicted yield 0.2255600541830063 T/ha // Real yield 0.20000000298023224 T/ha
# 526) Predicted yield 0.4476003646850586 T/ha // Real yield 0.15000000596046448 T/ha
# 527) Predicted yield 0.9044806361198425 T/ha // Real yield 1.5384615659713745 T/ha
# 528) Predicted yield 0.884585976600647 T/ha // Real yield 0.875 T/ha
# 529) Predicted yield 1.2012131214141846 T/ha // Real yield 0.8999999761581421 T/ha
# 530) Predicted yield 0.44705212116241455 T/ha // Real yield 0.25 T/ha
# 531) Predicted yield 0.49579110741615295 T/ha // Real yield 0.4000000059604645 T/ha
# 532) Predicted yield 0.5945681929588318 T/ha // Real yield 0.800000011920929 T/ha
# 533) Predicted yield 0.7460845708847046 T/ha // Real yield 1.0 T/ha
# 534) Predicted yield 0.39301151037216187 T/ha // Real yield 0.550000011920929 T/ha
# 535) Predicted yield 0.5552899837493896 T/ha // Real yield 0.0949999988079071 T/ha
# 536) Predicted yield 0.8875330686569214 T/ha // Real yield 0.15000000596046448 T/ha
# 537) Predicted yield 1.084514856338501 T/ha // Real yield 0.800000011920929 T/ha
# 538) Predicted yield 0.3619470000267029 T/ha // Real yield 0.1666666716337204 T/ha
# 539) Predicted yield 0.6222763061523438 T/ha // Real yield 0.6000000238418579 T/ha
# 540) Predicted yield 3.7326910495758057 T/ha // Real yield 6.0 T/ha
# 541) Predicted yield 0.24267427623271942 T/ha // Real yield 0.25 T/ha
# 542) Predicted yield 1.1748970746994019 T/ha // Real yield 0.6000000238418579 T/ha
# 543) Predicted yield 0.21473504602909088 T/ha // Real yield 0.25 T/ha
# 544) Predicted yield 0.5708940029144287 T/ha // Real yield 0.5 T/ha
# 545) Predicted yield 0.8463611602783203 T/ha // Real yield 0.800000011920929 T/ha
# 546) Predicted yield 1.143192172050476 T/ha // Real yield 1.100000023841858 T/ha
# 547) Predicted yield 0.5862377285957336 T/ha // Real yield 0.4000000059604645 T/ha
# 548) Predicted yield 0.7937783002853394 T/ha // Real yield 0.8571428656578064 T/ha
# 549) Predicted yield 0.5234997868537903 T/ha // Real yield 0.27000001072883606 T/ha
# 550) Predicted yield 0.478817880153656 T/ha // Real yield 0.10000000149011612 T/ha
# 551) Predicted yield 0.3835631310939789 T/ha // Real yield 0.4320000112056732 T/ha
# 552) Predicted yield 0.6923137903213501 T/ha // Real yield 0.30000001192092896 T/ha
# 553) Predicted yield 0.4002944231033325 T/ha // Real yield 0.02857142873108387 T/ha
# 554) Predicted yield 0.5729289650917053 T/ha // Real yield 0.75 T/ha
# 555) Predicted yield 0.3554309010505676 T/ha // Real yield 0.07000000029802322 T/ha
# 556) Predicted yield 0.3891482949256897 T/ha // Real yield 0.4000000059604645 T/ha
# 557) Predicted yield 0.6190738677978516 T/ha // Real yield 0.800000011920929 T/ha
# 558) Predicted yield 0.8086836338043213 T/ha // Real yield 0.5333333611488342 T/ha
# 559) Predicted yield 0.9012271165847778 T/ha // Real yield 0.6666666865348816 T/ha
# 560) Predicted yield 0.8345738053321838 T/ha // Real yield 0.800000011920929 T/ha
# 561) Predicted yield 0.29010719060897827 T/ha // Real yield 0.20000000298023224 T/ha
# 562) Predicted yield 0.5451745986938477 T/ha // Real yield 0.6000000238418579 T/ha
# 563) Predicted yield 0.9834499359130859 T/ha // Real yield 1.5 T/ha
# 564) Predicted yield 0.5215012431144714 T/ha // Real yield 0.23333333432674408 T/ha
# 565) Predicted yield 0.8446828126907349 T/ha // Real yield 0.3499999940395355 T/ha
# 566) Predicted yield 0.544364869594574 T/ha // Real yield 0.5 T/ha
# 567) Predicted yield 0.3488055467605591 T/ha // Real yield 0.10000000149011612 T/ha
# 568) Predicted yield 0.6619194746017456 T/ha // Real yield 0.30000001192092896 T/ha
# 569) Predicted yield 0.33855143189430237 T/ha // Real yield 0.15000000596046448 T/ha
# 570) Predicted yield 0.4876994490623474 T/ha // Real yield 0.05000000074505806 T/ha
# 571) Predicted yield 0.2707861065864563 T/ha // Real yield 0.05999999865889549 T/ha
# 572) Predicted yield 0.25024545192718506 T/ha // Real yield 0.10000000149011612 T/ha
# 573) Predicted yield 0.49821409583091736 T/ha // Real yield 0.6000000238418579 T/ha
# 574) Predicted yield 0.8540689945220947 T/ha // Real yield 1.5 T/ha
# 575) Predicted yield 0.48300445079803467 T/ha // Real yield 0.6666666865348816 T/ha
# 576) Predicted yield 1.1612344980239868 T/ha // Real yield 1.2999999523162842 T/ha
# 577) Predicted yield 0.5121270418167114 T/ha // Real yield 0.22499999403953552 T/ha
# 578) Predicted yield 0.7752308249473572 T/ha // Real yield 1.0 T/ha
# 579) Predicted yield 0.7037747502326965 T/ha // Real yield 0.41999998688697815 T/ha
# 580) Predicted yield 0.21309243142604828 T/ha // Real yield 0.25 T/ha
# 581) Predicted yield 0.5810837149620056 T/ha // Real yield 1.2000000476837158 T/ha
# 582) Predicted yield 0.5946643948554993 T/ha // Real yield 0.550000011920929 T/ha
# 583) Predicted yield 0.5311518311500549 T/ha // Real yield 0.699999988079071 T/ha
# 584) Predicted yield 0.35304397344589233 T/ha // Real yield 0.5 T/ha
# 585) Predicted yield 0.4184757471084595 T/ha // Real yield 0.800000011920929 T/ha
# 586) Predicted yield 0.6106364727020264 T/ha // Real yield 0.625 T/ha
# 587) Predicted yield 0.5282612442970276 T/ha // Real yield 0.4000000059604645 T/ha
# 588) Predicted yield 0.5443723201751709 T/ha // Real yield 0.20000000298023224 T/ha
# 589) Predicted yield 1.0118802785873413 T/ha // Real yield 1.0666667222976685 T/ha
# 590) Predicted yield 0.8032028675079346 T/ha // Real yield 0.6000000238418579 T/ha
# 591) Predicted yield 0.6952893733978271 T/ha // Real yield 0.4000000059604645 T/ha
# 592) Predicted yield 0.8074122071266174 T/ha // Real yield 0.6000000238418579 T/ha
# 593) Predicted yield 0.2786041796207428 T/ha // Real yield 0.17499999701976776 T/ha
# 594) Predicted yield 0.38753390312194824 T/ha // Real yield 0.125 T/ha
# 595) Predicted yield 0.8600645065307617 T/ha // Real yield 0.4285714328289032 T/ha
# 596) Predicted yield 0.32809212803840637 T/ha // Real yield 0.10000000149011612 T/ha
# 597) Predicted yield 0.3158101439476013 T/ha // Real yield 0.4000000059604645 T/ha
# 598) Predicted yield 0.30576813220977783 T/ha // Real yield 0.25 T/ha
# 599) Predicted yield 0.0801946222782135 T/ha // Real yield 0.10000000149011612 T/ha
# 600) Predicted yield 0.8143993020057678 T/ha // Real yield 0.36666667461395264 T/ha
# 601) Predicted yield 0.6474945545196533 T/ha // Real yield 0.020400000736117363 T/ha
# 602) Predicted yield 0.6908339858055115 T/ha // Real yield 0.4000000059604645 T/ha
# 603) Predicted yield 0.6903277039527893 T/ha // Real yield 0.6000000238418579 T/ha
# 604) Predicted yield 0.43628501892089844 T/ha // Real yield 0.3199999928474426 T/ha
# ...
# 815) Predicted yield 0.6204386949539185 T/ha // Real yield 1.0 T/ha
# 816) Predicted yield 0.3509759306907654 T/ha // Real yield 0.550000011920929 T/ha
# 817) Predicted yield 0.5198368430137634 T/ha // Real yield 0.38333332538604736 T/ha
# 818) Predicted yield 0.35234352946281433 T/ha // Real yield 0.1666666716337204 T/ha
# 819) Predicted yield 0.5697076916694641 T/ha // Real yield 0.23333333432674408 T/ha
# 820) Predicted yield 0.26520249247550964 T/ha // Real yield 0.4000000059604645 T/ha
# 821) Predicted yield 0.36409854888916016 T/ha // Real yield 0.5 T/ha
# 822) Predicted yield 0.7873101234436035 T/ha // Real yield 0.5 T/ha
# 823) Predicted yield 0.556385338306427 T/ha // Real yield 0.44999998807907104 T/ha
# 824) Predicted yield 0.2743872404098511 T/ha // Real yield 0.30000001192092896 T/ha
# 825) Predicted yield 0.7336862683296204 T/ha // Real yield 0.699999988079071 T/ha
# 826) Predicted yield 0.317376971244812 T/ha // Real yield 0.019999999552965164 T/ha
# 827) Predicted yield 0.8741530179977417 T/ha // Real yield 1.2300000190734863 T/ha
# 828) Predicted yield 0.3887611925601959 T/ha // Real yield 0.30000001192092896 T/ha
# 829) Predicted yield 0.2907589077949524 T/ha // Real yield 0.0625 T/ha
# 830) Predicted yield 0.4847605526447296 T/ha // Real yield 0.4000000059604645 T/ha
# 831) Predicted yield 0.7086927890777588 T/ha // Real yield 0.5 T/ha
# 832) Predicted yield 0.7167985439300537 T/ha // Real yield 0.75 T/ha
# 833) Predicted yield 0.10610741376876831 T/ha // Real yield 0.03333333507180214 T/ha
# 834) Predicted yield 0.5997512936592102 T/ha // Real yield 0.6000000238418579 T/ha
# 835) Predicted yield 0.548569917678833 T/ha // Real yield 0.5 T/ha
# 836) Predicted yield 0.4204406142234802 T/ha // Real yield 0.25 T/ha
# 837) Predicted yield 0.5071685910224915 T/ha // Real yield 0.6666666865348816 T/ha
# 838) Predicted yield 0.8901615142822266 T/ha // Real yield 0.5 T/ha
# 839) Predicted yield 0.9975080490112305 T/ha // Real yield 1.3333333730697632 T/ha
# 840) Predicted yield 0.40539106726646423 T/ha // Real yield 0.5 T/ha
# 841) Predicted yield 0.27136528491973877 T/ha // Real yield 0.3333333432674408 T/ha
# 842) Predicted yield 0.47928088903427124 T/ha // Real yield 0.375 T/ha
# 843) Predicted yield -0.042112670838832855 T/ha // Real yield 0.019999999552965164 T/ha
# 844) Predicted yield 0.6432378888130188 T/ha // Real yield 0.4000000059604645 T/ha
# 845) Predicted yield 0.364326536655426 T/ha // Real yield 0.5 T/ha
# 846) Predicted yield 0.6074143052101135 T/ha // Real yield 1.0 T/ha
# 847) Predicted yield 0.49571678042411804 T/ha // Real yield 0.4000000059604645 T/ha
# 848) Predicted yield 0.3366331160068512 T/ha // Real yield 0.07500000298023224 T/ha
# 849) Predicted yield 0.5401753187179565 T/ha // Real yield 1.0 T/ha
# 850) Predicted yield 0.44187095761299133 T/ha // Real yield 0.8799999952316284 T/ha
# 851) Predicted yield 0.8557229042053223 T/ha // Real yield 0.30000001192092896 T/ha
# 852) Predicted yield 0.27853912115097046 T/ha // Real yield 0.05000000074505806 T/ha
# 853) Predicted yield 0.5278691053390503 T/ha // Real yield 0.6000000238418579 T/ha
# 854) Predicted yield 0.18537861108779907 T/ha // Real yield 0.375 T/ha
# 855) Predicted yield 0.6377491354942322 T/ha // Real yield 0.8999999761581421 T/ha
# 856) Predicted yield 0.36585181951522827 T/ha // Real yield 0.30000001192092896 T/ha
# 857) Predicted yield 0.5101893544197083 T/ha // Real yield 0.6666666865348816 T/ha
# 858) Predicted yield 0.2839431166648865 T/ha // Real yield 0.3499999940395355 T/ha
# 859) Predicted yield 0.9014136791229248 T/ha // Real yield 0.4166666567325592 T/ha
# 860) Predicted yield 0.702815055847168 T/ha // Real yield 0.800000011920929 T/ha
# 861) Predicted yield 0.14887213706970215 T/ha // Real yield 0.04800000041723251 T/ha
# 862) Predicted yield 0.5177436470985413 T/ha // Real yield 0.550000011920929 T/ha
# 863) Predicted yield 0.786550760269165 T/ha // Real yield 1.25 T/ha
# 864) Predicted yield 0.5281059145927429 T/ha // Real yield 0.3166666626930237 T/ha
# 865) Predicted yield 0.48695605993270874 T/ha // Real yield 0.5 T/ha
# 866) Predicted yield 0.44686365127563477 T/ha // Real yield 0.6399999856948853 T/ha
# 867) Predicted yield 0.5686625242233276 T/ha // Real yield 0.25 T/ha
# 868) Predicted yield 0.3924201726913452 T/ha // Real yield 0.6000000238418579 T/ha
# 869) Predicted yield 0.7821053266525269 T/ha // Real yield 0.375 T/ha
# 870) Predicted yield 0.851762592792511 T/ha // Real yield 1.0 T/ha
# 871) Predicted yield 0.9793931245803833 T/ha // Real yield 0.6666666865348816 T/ha
# 872) Predicted yield 0.5510079860687256 T/ha // Real yield 0.30000001192092896 T/ha
# 873) Predicted yield 0.4597119092941284 T/ha // Real yield 0.30000001192092896 T/ha
# 874) Predicted yield 0.8594450950622559 T/ha // Real yield 0.7272727489471436 T/ha
# 875) Predicted yield 0.4107489287853241 T/ha // Real yield 0.15000000596046448 T/ha
# 876) Predicted yield 0.37526288628578186 T/ha // Real yield 0.36000001430511475 T/ha
# 877) Predicted yield 0.9284365177154541 T/ha // Real yield 0.6666666865348816 T/ha
# 878) Predicted yield 0.238523930311203 T/ha // Real yield 0.15000000596046448 T/ha
# 879) Predicted yield 0.40850937366485596 T/ha // Real yield 0.3333333432674408 T/ha
# 880) Predicted yield 0.616606593132019 T/ha // Real yield 0.7333333492279053 T/ha
# 881) Predicted yield 1.0376192331314087 T/ha // Real yield 1.25 T/ha
# 882) Predicted yield 0.7093113660812378 T/ha // Real yield 0.30000001192092896 T/ha
# 883) Predicted yield 0.7232753038406372 T/ha // Real yield 0.6000000238418579 T/ha
# 884) Predicted yield 0.7657966017723083 T/ha // Real yield 0.6150000095367432 T/ha
# 885) Predicted yield 0.7554745674133301 T/ha // Real yield 0.22499999403953552 T/ha
# 886) Predicted yield 0.6733490824699402 T/ha // Real yield 1.0 T/ha
# 887) Predicted yield 0.6744217276573181 T/ha // Real yield 0.800000011920929 T/ha
# 888) Predicted yield 0.2694847881793976 T/ha // Real yield 0.09000000357627869 T/ha
# 889) Predicted yield 0.27058884501457214 T/ha // Real yield 0.44999998807907104 T/ha
# 890) Predicted yield 0.38528740406036377 T/ha // Real yield 1.2000000476837158 T/ha
# 891) Predicted yield 0.616337239742279 T/ha // Real yield 0.8999999761581421 T/ha
# 892) Predicted yield 0.2858484983444214 T/ha // Real yield 0.20000000298023224 T/ha
# 893) Predicted yield 0.192681223154068 T/ha // Real yield 0.03999999910593033 T/ha
# 894) Predicted yield 0.52635657787323 T/ha // Real yield 0.6000000238418579 T/ha
# 895) Predicted yield 0.5505020618438721 T/ha // Real yield 0.4000000059604645 T/ha
# 896) Predicted yield 0.2627405524253845 T/ha // Real yield 0.02500000037252903 T/ha
# 897) Predicted yield 0.8132825493812561 T/ha // Real yield 1.5 T/ha
# 898) Predicted yield 0.9597669243812561 T/ha // Real yield 1.0 T/ha
# 899) Predicted yield 0.6298333406448364 T/ha // Real yield 0.800000011920929 T/ha
# 900) Predicted yield 0.22720853984355927 T/ha // Real yield 0.25 T/ha
# 901) Predicted yield 4.945727825164795 T/ha // Real yield 5.0 T/ha
# 902) Predicted yield 0.8866050839424133 T/ha // Real yield 0.30000001192092896 T/ha
# 903) Predicted yield 0.15524530410766602 T/ha // Real yield 0.11249999701976776 T/ha
# 904) Predicted yield 0.6971844434738159 T/ha // Real yield 1.2000000476837158 T/ha
# 905) Predicted yield 0.6185438632965088 T/ha // Real yield 0.25 T/ha
# 906) Predicted yield 1.1064488887786865 T/ha // Real yield 1.5 T/ha
# 907) Predicted yield 0.5128654837608337 T/ha // Real yield 0.6000000238418579 T/ha
# 908) Predicted yield 0.29803842306137085 T/ha // Real yield 0.15000000596046448 T/ha
# 909) Predicted yield 0.36657190322875977 T/ha // Real yield 0.10000000149011612 T/ha
# 910) Predicted yield 0.6561849117279053 T/ha // Real yield 0.1666666716337204 T/ha
# 911) Predicted yield 0.7972519993782043 T/ha // Real yield 0.5 T/ha
# 912) Predicted yield 0.6875045299530029 T/ha // Real yield 1.100000023841858 T/ha
# 913) Predicted yield 0.005389417987316847 T/ha // Real yield 0.10000000149011612 T/ha
# 914) Predicted yield 0.7532245516777039 T/ha // Real yield 0.20000000298023224 T/ha
# 915) Predicted yield 0.3973187208175659 T/ha // Real yield 0.05000000074505806 T/ha
# 916) Predicted yield 0.3580954372882843 T/ha // Real yield 0.3466666638851166 T/ha
# 917) Predicted yield 0.2220524698495865 T/ha // Real yield 0.30000001192092896 T/ha
# 918) Predicted yield 0.438713401556015 T/ha // Real yield 0.4000000059604645 T/ha
# 919) Predicted yield 0.43314725160598755 T/ha // Real yield 0.17499999701976776 T/ha
# 920) Predicted yield 0.5580136775970459 T/ha // Real yield 0.7333333492279053 T/ha
# 921) Predicted yield 0.48914507031440735 T/ha // Real yield 0.18000000715255737 T/ha
# 922) Predicted yield 0.942693829536438 T/ha // Real yield 1.0 T/ha
# 923) Predicted yield 0.4038807153701782 T/ha // Real yield 0.23333333432674408 T/ha
# 924) Predicted yield 0.6801670789718628 T/ha // Real yield 1.0 T/ha
# 925) Predicted yield 0.4165385663509369 T/ha // Real yield 0.125 T/ha
# 926) Predicted yield 0.39369910955429077 T/ha // Real yield 0.25 T/ha
# 927) Predicted yield 0.8192994594573975 T/ha // Real yield 0.800000011920929 T/ha
# 928) Predicted yield 0.8268557786941528 T/ha // Real yield 1.399999976158142 T/ha
# 929) Predicted yield 0.5113814473152161 T/ha // Real yield 0.4000000059604645 T/ha
# 930) Predicted yield 0.5107807517051697 T/ha // Real yield 0.375 T/ha
# 931) Predicted yield 0.9312477111816406 T/ha // Real yield 1.0 T/ha
# 932) Predicted yield 0.9834904074668884 T/ha // Real yield 1.0 T/ha
# 933) Predicted yield 0.9549225568771362 T/ha // Real yield 1.0 T/ha
# 934) Predicted yield 0.5624395608901978 T/ha // Real yield 0.699999988079071 T/ha
# 935) Predicted yield -0.004769408144056797 T/ha // Real yield 0.5 T/ha
# 936) Predicted yield 0.38036617636680603 T/ha // Real yield 0.02500000037252903 T/ha
# 937) Predicted yield 0.5613505840301514 T/ha // Real yield 0.15000000596046448 T/ha
# 938) Predicted yield 0.41701602935791016 T/ha // Real yield 0.2857142984867096 T/ha
# 939) Predicted yield 0.29416343569755554 T/ha // Real yield 0.30000001192092896 T/ha
# 940) Predicted yield 0.5485360026359558 T/ha // Real yield 0.6000000238418579 T/ha
# 941) Predicted yield 0.5661689043045044 T/ha // Real yield 0.5 T/ha
# 942) Predicted yield 0.3138744831085205 T/ha // Real yield 1.0 T/ha
# 943) Predicted yield 0.5663388967514038 T/ha // Real yield 0.1666666716337204 T/ha
# 944) Predicted yield 0.5652032494544983 T/ha // Real yield 0.800000011920929 T/ha
# 945) Predicted yield 0.7036044597625732 T/ha // Real yield 0.5 T/ha
# 946) Predicted yield 0.487607479095459 T/ha // Real yield 1.5 T/ha
# 947) Predicted yield 0.3345370888710022 T/ha // Real yield 0.25 T/ha
# 948) Predicted yield 0.5686374306678772 T/ha // Real yield 0.75 T/ha
# 949) Predicted yield 2.6583502292633057 T/ha // Real yield 0.05000000074505806 T/ha
# 950) Predicted yield 0.9583511352539062 T/ha // Real yield 0.5 T/ha
# 951) Predicted yield 0.6494813561439514 T/ha // Real yield 0.2666666805744171 T/ha
# 952) Predicted yield 0.6121013164520264 T/ha // Real yield 1.0 T/ha
# 953) Predicted yield 0.40985530614852905 T/ha // Real yield 0.25 T/ha
# 954) Predicted yield 0.3752451539039612 T/ha // Real yield 0.4000000059604645 T/ha
# 955) Predicted yield 0.7038962841033936 T/ha // Real yield 0.75 T/ha
# 956) Predicted yield 0.5553484559059143 T/ha // Real yield 0.800000011920929 T/ha
# 957) Predicted yield 0.44897857308387756 T/ha // Real yield 0.30000001192092896 T/ha
# 958) Predicted yield 0.7269402742385864 T/ha // Real yield 0.5333333611488342 T/ha
# 959) Predicted yield 0.7244695425033569 T/ha // Real yield 0.4333333373069763 T/ha
# 960) Predicted yield 0.9331799745559692 T/ha // Real yield 1.0 T/ha
# 961) Predicted yield 0.5295091867446899 T/ha // Real yield 0.550000011920929 T/ha
# 962) Predicted yield 0.5601391196250916 T/ha // Real yield 0.4000000059604645 T/ha
# 963) Predicted yield 0.304627925157547 T/ha // Real yield 0.15000000596046448 T/ha
# 964) Predicted yield 0.2770254909992218 T/ha // Real yield 0.25 T/ha
# 965) Predicted yield 0.7953768968582153 T/ha // Real yield 0.5249999761581421 T/ha
# 966) Predicted yield 0.6929105520248413 T/ha // Real yield 0.25 T/ha
# 967) Predicted yield 0.6305177807807922 T/ha // Real yield 0.699999988079071 T/ha
# 968) Predicted yield 1.1865988969802856 T/ha // Real yield 1.0 T/ha
# 969) Predicted yield 0.4827623963356018 T/ha // Real yield 0.23999999463558197 T/ha
# 970) Predicted yield 0.756201982498169 T/ha // Real yield 0.4000000059604645 T/ha
# 971) Predicted yield 0.7179458141326904 T/ha // Real yield 0.6000000238418579 T/ha
# 972) Predicted yield 1.272915244102478 T/ha // Real yield 2.549999952316284 T/ha
# 973) Predicted yield 0.7153847813606262 T/ha // Real yield 0.5555555820465088 T/ha
# 974) Predicted yield 0.5775097608566284 T/ha // Real yield 0.4000000059604645 T/ha
# 975) Predicted yield 0.4855304956436157 T/ha // Real yield 0.6499999761581421 T/ha
# 976) Predicted yield 0.2891823649406433 T/ha // Real yield 0.5 T/ha
# 977) Predicted yield 0.24489158391952515 T/ha // Real yield 0.30000001192092896 T/ha
# 978) Predicted yield 1.0625598430633545 T/ha // Real yield 1.2000000476837158 T/ha
# 979) Predicted yield 0.9400126338005066 T/ha // Real yield 0.4000000059604645 T/ha
# 980) Predicted yield 0.8721212148666382 T/ha // Real yield 1.2000000476837158 T/ha
# 981) Predicted yield 0.5929135084152222 T/ha // Real yield 0.5 T/ha
# 982) Predicted yield 0.9158961772918701 T/ha // Real yield 0.3333333432674408 T/ha
# 983) Predicted yield 0.4393949806690216 T/ha // Real yield 0.1666666716337204 T/ha
# 984) Predicted yield 0.4031863510608673 T/ha // Real yield 0.625 T/ha
# 985) Predicted yield 0.7396395802497864 T/ha // Real yield 1.0 T/ha
# 986) Predicted yield 0.5079357624053955 T/ha // Real yield 0.3333333432674408 T/ha
# 987) Predicted yield 0.36314627528190613 T/ha // Real yield 0.00800000037997961 T/ha
# 988) Predicted yield 0.524985671043396 T/ha // Real yield 0.2750000059604645 T/ha
# 989) Predicted yield 1.1982065439224243 T/ha // Real yield 1.0 T/ha
# 990) Predicted yield 1.0682475566864014 T/ha // Real yield 1.2000000476837158 T/ha
# 991) Predicted yield 0.3028630018234253 T/ha // Real yield 0.15000000596046448 T/ha
# 992) Predicted yield 0.694383978843689 T/ha // Real yield 0.11999999731779099 T/ha
# 993) Predicted yield 0.47160255908966064 T/ha // Real yield 0.5 T/ha
# 994) Predicted yield 0.9509995579719543 T/ha // Real yield 1.0 T/ha
# 995) Predicted yield 0.32300007343292236 T/ha // Real yield 0.06666667014360428 T/ha
# 996) Predicted yield 0.4506961405277252 T/ha // Real yield 0.05000000074505806 T/ha
# 997) Predicted yield 1.2763075828552246 T/ha // Real yield 1.25 T/ha
# 998) Predicted yield 0.5359213948249817 T/ha // Real yield 0.7360000014305115 T/ha
# 999) Predicted yield 0.5831970572471619 T/ha // Real yield 0.574999988079071 T/ha
# 1000) Predicted yield 2.37436842918396 T/ha // Real yield 0.699999988079071 T/ha
# 1001) Predicted yield 0.44177213311195374 T/ha // Real yield 0.25 T/ha
# 1002) Predicted yield 0.29183003306388855 T/ha // Real yield 0.30000001192092896 T/ha
# 1003) Predicted yield 0.7502896785736084 T/ha // Real yield 0.5 T/ha
# 1004) Predicted yield 0.15749861299991608 T/ha // Real yield 0.10000000149011612 T/ha
# 1005) Predicted yield 0.6655519008636475 T/ha // Real yield 0.75 T/ha
# 1006) Predicted yield 0.3639945387840271 T/ha // Real yield 0.6000000238418579 T/ha
# 1007) Predicted yield 0.45106568932533264 T/ha // Real yield 0.5 T/ha
# 1008) Predicted yield 0.9687545299530029 T/ha // Real yield 1.0 T/ha
# 1009) Predicted yield 0.4965178072452545 T/ha // Real yield 0.20000000298023224 T/ha
# 1010) Predicted yield 0.30525290966033936 T/ha // Real yield 0.20000000298023224 T/ha
# 1011) Predicted yield 0.8052006363868713 T/ha // Real yield 1.399999976158142 T/ha
# 1012) Predicted yield 0.35535112023353577 T/ha // Real yield 0.8999999761581421 T/ha
# 1013) Predicted yield 0.22287051379680634 T/ha // Real yield 0.02500000037252903 T/ha
# 1014) Predicted yield 0.7550068497657776 T/ha // Real yield 1.0 T/ha
# 1015) Predicted yield 0.3357773721218109 T/ha // Real yield 0.03200000151991844 T/ha
# 1016) Predicted yield 0.5393446087837219 T/ha // Real yield 0.20000000298023224 T/ha
# 1017) Predicted yield 0.18931066989898682 T/ha // Real yield 0.20000000298023224 T/ha
